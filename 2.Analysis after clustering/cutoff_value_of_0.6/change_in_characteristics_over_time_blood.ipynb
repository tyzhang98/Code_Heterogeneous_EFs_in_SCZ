# %% [markdown]
# ## 控制社会人口学信息

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import mixedlm
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multicomp import MultiComparison
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import warnings

warnings.filterwarnings('ignore')

# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet2')

# 删除 'Cluster' 列中等于 3 的行
data_cleaned = data[data['Cluster'] != 3]

data = data_cleaned

# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [

    ("CK_baseline", "CK_followup"),
    ("TG_baseline", "TG_followup"),
    ("CHOL_baseline", "CHOL_followup"),
    ("HDLC_baseline", "HDLC_followup"),
    ("LDLC_baseline", "LDLC_followup")
]

# 添加主题列
data['Subject'] = data.index
data = data.reset_index(drop=True)

# 确保所有列名一致
required_columns = [
    'Cluster', 'Subject', 'Age', 
    'Education_years', 'Gender']

missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"The following required columns are missing from the data: {missing_columns}")

# 创建字典以存储结果
results = {}

# 对每个变量进行线性混合效应模型分析
def perform_lmm_analysis(baseline_var, followup_var):
    # 确保变量名一致
    baseline_var = baseline_var.replace(' ', '_')
    followup_var = followup_var.replace(' ', '_')

    # 数据重塑为长格式
    df_long = pd.melt(data, id_vars=required_columns, 
                      value_vars=[baseline_var, followup_var], 
                      var_name='Time', value_name='Score')
    
    df_long['Time'] = df_long['Time'].map({baseline_var: 0, followup_var: 1})
    df_long['Cluster'] = df_long['Cluster'].astype('category')
    
    # 哑变量生成
    df_long = pd.get_dummies(df_long, columns=[
        'Gender'], drop_first=True)

    # 定义线性混合效应模型公式
    formula = ("Score ~ Time * Cluster + Age + "
               "Education_years + " +
               " + ".join(df_long.columns[df_long.columns.str.startswith(('Gender_'))]))
    
    md = mixedlm(formula, df_long, groups=df_long["Subject"], re_formula="~Time")
    mdf = md.fit()
    
    # 提取固定效应的p值
    p_values = mdf.pvalues.loc[['Time', 'Cluster[T.1]', 'Time:Cluster[T.1]']]

    # 多重比较校正
    _, p_values_corrected, _, _ = multipletests(p_values, method='fdr_bh', is_sorted=False)
    p_values_corrected_dict = dict(zip(p_values.index, p_values_corrected))

    # 存储结果
    return {
        'LMM_summary': mdf.summary(),
        'Time_pvalue': p_values.loc['Time'],
        'Cluster_pvalue': p_values.loc['Cluster[T.1]'],
        'Interaction_pvalue': p_values.loc['Time:Cluster[T.1]'],
        'Time_pvalue_corrected': p_values_corrected_dict['Time'],
        'Cluster_pvalue_corrected': p_values_corrected_dict['Cluster[T.1]'],
        'Interaction_pvalue_corrected': p_values_corrected_dict['Time:Cluster[T.1]'],
        'df_long': df_long  # Store the long format data for post-hoc analysis
    }

# 对每个变量进行分析并存储结果
for baseline_var, followup_var in variables:
    results[baseline_var] = perform_lmm_analysis(baseline_var, followup_var)

# 定义绘图函数
def plot_interaction(df_long, var_name):
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette="muted")

    plt.title(f'Interaction Plot for {var_name}')
    plt.xlabel('Time')
    plt.ylabel('Score')
    plt.xticks([0, 1], ['Baseline', 'Follow-up'])
    plt.legend(title='Cluster', loc='upper left')
    plt.tight_layout()
    plt.show()

# 输出结果
for var, result in results.items():
    print(f"Variable: {var}")
    print(result['LMM_summary'])
    print(f"Time p-value (corrected): {result['Time_pvalue_corrected']:.3f}")
    print(f"Cluster p-value (corrected): {result['Cluster_pvalue_corrected']:.3f}")
    print(f"Interaction p-value (corrected): {result['Interaction_pvalue_corrected']:.3f}")

    # 进行事后比较
    if result['Interaction_pvalue_corrected'] < 0.05:  # Check for significance
        mc = MultiComparison(result['df_long']['Score'], 
                             result['df_long']['Time'].astype(str) + "_" + result['df_long']['Cluster'].astype(str))
        post_hoc_results = mc.tukeyhsd(alpha=0.05)

        # 修改Tukey HSD表的显示
        summary_df = pd.DataFrame(data=post_hoc_results.summary().data[1:], columns=post_hoc_results.summary().data[0])
        summary_df['group1'] = summary_df['group1'].replace({'0_0': 'baseline_Subtype I', '0_1': 'baseline_Subtype II', 
                                                             '1_0': 'followup_Subtype I', '1_1': 'followup_Subtype II'})
        summary_df['group2'] = summary_df['group2'].replace({'0_0': 'baseline_Subtype I', '0_1': 'baseline_Subtype II', 
                                                             '1_0': 'followup_Subtype I', '1_1': 'followup_Subtype II'})
        print(tabulate(summary_df, headers='keys', tablefmt='pretty'))

        # 输出均值和标准差
        means = result['df_long'].groupby(['Time', 'Cluster'])['Score'].agg(['mean', 'std']).reset_index()
        means['Cluster'] = means['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
        means['Time'] = means['Time'].map({0: 'baseline', 1: 'followup'})
        
        for idx, row in means.iterrows():
            print(f"Cluster: {row['Cluster']}, Time: {row['Time']}, Mean: {row['mean']:.2f}, Std: {row['std']:.2f}")
    print("---")
# Out:
# Variable: CK_baseline
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                MixedLM    Dependent Variable:    Score
# No. Observations:     156        Method:                REML
# No. Groups:           78         Scale:                 1088.0889
# Min. group size:      2          Log-Likelihood:        -806.2784
# Max. group size:      2          Converged:             No
# Mean group size:      2.0
# -----------------------------------------------------------------
#                     Coef.   Std.Err.   z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           104.657   21.790  4.803 0.000  61.949 147.364
# Cluster[T.1]        -16.563   15.306 -1.082 0.279 -46.562  13.436
# Time                -22.125   12.556 -1.762 0.078 -46.735   2.485
# Time:Cluster[T.1]    15.484   16.176  0.957 0.338 -16.219  47.188
# Age                  -0.217    0.449 -0.483 0.629  -1.097   0.663
# Education_years       0.123    1.088  0.113 0.910  -2.009   2.254
# Gender_2             -2.175    8.985 -0.242 0.809 -19.785  15.435
# Group Var          3077.836
# Group x Time Cov  -2782.668
# Time Var           2711.369
# =================================================================
#
# Time p-value (corrected): 0.234
# Cluster p-value (corrected): 0.338
# Interaction p-value (corrected): 0.338
# ---
# Variable: TG_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               0.2933
# Min. group size:     2        Log-Likelihood:      -183.1356
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          1.711    0.356  4.807 0.000  1.013  2.409
# Cluster[T.1]      -0.100    0.176 -0.568 0.570 -0.445  0.245
# Time              -0.041    0.165 -0.251 0.802 -0.364  0.281
# Time:Cluster[T.1]  0.157    0.212  0.742 0.458 -0.258  0.573
# Age               -0.007    0.008 -0.905 0.366 -0.023  0.008
# Education_years    0.023    0.020  1.198 0.231 -0.015  0.062
# Gender_2          -0.378    0.161 -2.349 0.019 -0.693 -0.063
# Group Var          0.218
# Group x Time Cov  -0.071
# Time Var           0.253
# ============================================================
#
# Time p-value (corrected): 0.802
# Cluster p-value (corrected): 0.802
# Interaction p-value (corrected): 0.802
# ---
# Variable: CHOL_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               0.5406
# Min. group size:     2        Log-Likelihood:      -218.5089
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          4.408    0.436 10.108 0.000  3.553  5.263
# Cluster[T.1]      -0.313    0.238 -1.319 0.187 -0.779  0.152
# Time              -0.188    0.218 -0.863 0.388 -0.616  0.239
# Time:Cluster[T.1]  0.408    0.281  1.452 0.146 -0.143  0.959
# Age               -0.008    0.010 -0.799 0.424 -0.027  0.011
# Education_years    0.000    0.024  0.010 0.992 -0.046  0.046
# Gender_2           0.126    0.194  0.646 0.519 -0.256  0.507
# Group Var          0.416
# Group x Time Cov  -0.266
# Time Var           0.395
# ============================================================
#
# Time p-value (corrected): 0.388
# Cluster p-value (corrected): 0.281
# Interaction p-value (corrected): 0.281
# ---
# Variable: HDLC_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:              MixedLM   Dependent Variable:   Score
# No. Observations:   156       Method:               REML
# No. Groups:         78        Scale:                0.0313
# Min. group size:    2         Log-Likelihood:       -25.4087
# Max. group size:    2         Converged:            Yes
# Mean group size:    2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          1.106    0.128  8.662 0.000  0.856  1.356
# Cluster[T.1]       0.076    0.060  1.255 0.209 -0.043  0.194
# Time               0.105    0.055  1.926 0.054 -0.002  0.212
# Time:Cluster[T.1] -0.078    0.070 -1.106 0.269 -0.216  0.060
# Age                0.003    0.003  1.028 0.304 -0.003  0.009
# Education_years   -0.014    0.007 -1.919 0.055 -0.027  0.000
# Gender_2           0.077    0.058  1.314 0.189 -0.038  0.191
# Group Var          0.028
# Group x Time Cov  -0.003
# Time Var           0.030
# ============================================================
#
# Time p-value (corrected): 0.162
# Cluster p-value (corrected): 0.269
# Interaction p-value (corrected): 0.269
# ---
# Variable: LDLC_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               0.3432
# Min. group size:     2        Log-Likelihood:      -187.8427
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          2.775    0.359  7.725 0.000  2.071  3.479
# Cluster[T.1]      -0.232    0.189 -1.225 0.220 -0.603  0.139
# Time              -0.147    0.175 -0.843 0.399 -0.489  0.195
# Time:Cluster[T.1]  0.317    0.225  1.409 0.159 -0.124  0.757
# Age               -0.008    0.008 -1.041 0.298 -0.024  0.007
# Education_years    0.014    0.020  0.722 0.470 -0.024  0.052
# Gender_2           0.076    0.161  0.473 0.636 -0.240  0.393
# Group Var          0.259
# Group x Time Cov  -0.140
# Time Var           0.258
# ============================================================
#
# Time p-value (corrected): 0.399
# Cluster p-value (corrected): 0.331
# Interaction p-value (corrected): 0.331
# ---

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import mixedlm
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multicomp import MultiComparison
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import warnings

warnings.filterwarnings('ignore')

# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet2')

# 删除 'Cluster' 列中等于 3 的行
data_cleaned = data[data['Cluster'] != 3]

data = data_cleaned

# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ( "WBC_baseline", "WBC_followup"),
    ("NEUT_baseline", "NEUT_followup"),
    ("LYMPH_baseline", "LYMPH_followup"),
    ("MONO_baseline", "MONO_followup"),
    ("PIL_baseline", "PIL_followup"),
    ("CRP_baseline", "CRP_followup"),
    ("NLR_baseline", "NLR_followup"),
    ("PLR_baseline", "PLR_followup"),
    ("MLR_baseline", "MLR_followup"),
    ("SIII_baseline", "SIII_followup"),
    ("ASTALT_baseline", "ASTALT_followup"),
    ("LDH_baseline", "LDH_followup"),
]

# 添加主题列
data['Subject'] = data.index
data = data.reset_index(drop=True)

# 确保所有列名一致
required_columns = [
    'Cluster', 'Subject',  'Age', 
    'Education_years', 'Gender']

missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"The following required columns are missing from the data: {missing_columns}")

# 创建字典以存储结果
results = {}

# 对每个变量进行线性混合效应模型分析
def perform_lmm_analysis(baseline_var, followup_var):
    # 确保变量名一致
    baseline_var = baseline_var.replace(' ', '_')
    followup_var = followup_var.replace(' ', '_')

    # 数据重塑为长格式
    df_long = pd.melt(data, id_vars=required_columns, 
                      value_vars=[baseline_var, followup_var], 
                      var_name='Time', value_name='Score')
    
    df_long['Time'] = df_long['Time'].map({baseline_var: 0, followup_var: 1})
    df_long['Cluster'] = df_long['Cluster'].astype('category')
    
    # 哑变量生成
    df_long = pd.get_dummies(df_long, columns=[
        'Gender'], drop_first=True)

    # 定义线性混合效应模型公式
    formula = ("Score ~ Time * Cluster + Age + "
               "Education_years + " +
               " + ".join(df_long.columns[df_long.columns.str.startswith(('Gender_'))]))
    
    md = mixedlm(formula, df_long, groups=df_long["Subject"], re_formula="~Time")
    mdf = md.fit()
    
    # 提取固定效应的p值
    p_values = mdf.pvalues.loc[['Time', 'Cluster[T.1]', 'Time:Cluster[T.1]']]

    # 多重比较校正
    _, p_values_corrected, _, _ = multipletests(p_values, method='fdr_bh', is_sorted=False)
    p_values_corrected_dict = dict(zip(p_values.index, p_values_corrected))

    # 存储结果
    return {
        'LMM_summary': mdf.summary(),
        'Time_pvalue': p_values.loc['Time'],
        'Cluster_pvalue': p_values.loc['Cluster[T.1]'],
        'Interaction_pvalue': p_values.loc['Time:Cluster[T.1]'],
        'Time_pvalue_corrected': p_values_corrected_dict['Time'],
        'Cluster_pvalue_corrected': p_values_corrected_dict['Cluster[T.1]'],
        'Interaction_pvalue_corrected': p_values_corrected_dict['Time:Cluster[T.1]'],
        'df_long': df_long  # Store the long format data for post-hoc analysis
    }

# 对每个变量进行分析并存储结果
for baseline_var, followup_var in variables:
    results[baseline_var] = perform_lmm_analysis(baseline_var, followup_var)

# 定义绘图函数
def plot_interaction(df_long, var_name):
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette="muted")

    plt.title(f'Interaction Plot for {var_name}')
    plt.xlabel('Time')
    plt.ylabel('Score')
    plt.xticks([0, 1], ['Baseline', 'Follow-up'])
    plt.legend(title='Cluster', loc='upper left')
    plt.tight_layout()
    plt.show()

# 输出结果
for var, result in results.items():
    print(f"Variable: {var}")
    print(result['LMM_summary'])
    print(f"Time p-value (corrected): {result['Time_pvalue_corrected']:.3f}")
    print(f"Cluster p-value (corrected): {result['Cluster_pvalue_corrected']:.3f}")
    print(f"Interaction p-value (corrected): {result['Interaction_pvalue_corrected']:.3f}")

    # 进行事后比较
    if result['Interaction_pvalue_corrected'] < 0.06:  # Check for significance
        mc = MultiComparison(result['df_long']['Score'], 
                             result['df_long']['Time'].astype(str) + "_" + result['df_long']['Cluster'].astype(str))
        post_hoc_results = mc.tukeyhsd(alpha=0.05)

        # 修改Tukey HSD表的显示
        summary_df = pd.DataFrame(data=post_hoc_results.summary().data[1:], columns=post_hoc_results.summary().data[0])
        summary_df['group1'] = summary_df['group1'].replace({'0_0': 'baseline_Subtype I', '0_1': 'baseline_Subtype II', 
                                                             '1_0': 'followup_Subtype I', '1_1': 'followup_Subtype II'})
        summary_df['group2'] = summary_df['group2'].replace({'0_0': 'baseline_Subtype I', '0_1': 'baseline_Subtype II', 
                                                             '1_0': 'followup_Subtype I', '1_1': 'followup_Subtype II'})
        print(tabulate(summary_df, headers='keys', tablefmt='pretty'))

        # 输出均值和标准差
        means = result['df_long'].groupby(['Time', 'Cluster'])['Score'].agg(['mean', 'std']).reset_index()
        means['Cluster'] = means['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
        means['Time'] = means['Time'].map({0: 'baseline', 1: 'followup'})
        
        for idx, row in means.iterrows():
            print(f"Cluster: {row['Cluster']}, Time: {row['Time']}, Mean: {row['mean']:.2f}, Std: {row['std']:.2f}")
    print("---")
# Out:
# Variable: WBC_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               0.8253
# Min. group size:     2        Log-Likelihood:      -281.5785
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          6.005    0.775  7.750 0.000  4.487  7.524
# Cluster[T.1]      -0.379    0.350 -1.083 0.279 -1.065  0.307
# Time               0.581    0.279  2.080 0.037  0.034  1.128
# Time:Cluster[T.1]  0.070    0.360  0.194 0.846 -0.635  0.775
# Age                0.013    0.018  0.724 0.469 -0.022  0.048
# Education_years   -0.040    0.043 -0.925 0.355 -0.125  0.045
# Gender_2          -0.031    0.358 -0.088 0.930 -0.732  0.669
# Group Var          1.129
# Group x Time Cov   0.105
# Time Var           0.765
# ============================================================
#
# Time p-value (corrected): 0.112
# Cluster p-value (corrected): 0.418
# Interaction p-value (corrected): 0.846
# ---
# Variable: NEUT_baseline
#             Mixed Linear Model Regression Results
# =============================================================
# Model:              MixedLM   Dependent Variable:   Score
# No. Observations:   156       Method:               REML
# No. Groups:         78        Scale:                46.2175
# Min. group size:    2         Log-Likelihood:       -564.0681
# Max. group size:    2         Converged:            Yes
# Mean group size:    2.0
# -------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------
# Intercept          57.739    4.797 12.036 0.000 48.337 67.142
# Cluster[T.1]        2.563    2.364  1.084 0.278 -2.070  7.196
# Time                1.920    2.021  0.950 0.342 -2.040  5.881
# Time:Cluster[T.1]   2.126    2.603  0.817 0.414 -2.976  7.228
# Age                -0.074    0.109 -0.678 0.498 -0.288  0.140
# Education_years     0.085    0.264  0.322 0.747 -0.433  0.603
# Gender_2           -1.833    2.181 -0.840 0.401 -6.108  2.443
# Group Var          45.742
# Group x Time Cov  -12.424
# Time Var           34.153
# =============================================================
#
# Time p-value (corrected): 0.414
# Cluster p-value (corrected): 0.414
# Interaction p-value (corrected): 0.414
# ---
# Variable: LYMPH_baseline
#             Mixed Linear Model Regression Results
# ==============================================================
# Model:               MixedLM   Dependent Variable:   Score
# No. Observations:    156       Method:               REML
# No. Groups:          78        Scale:                53.8512
# Min. group size:     2         Log-Likelihood:       -565.1355
# Max. group size:     2         Converged:            Yes
# Mean group size:     2.0
# --------------------------------------------------------------
#                    Coef.  Std.Err.   z    P>|z|  [0.025 0.975]
# --------------------------------------------------------------
# Intercept          36.334    4.495  8.084 0.000  27.525 45.144
# Cluster[T.1]       -2.840    2.337 -1.215 0.224  -7.421  1.741
# Time               -7.217    2.202 -3.277 0.001 -11.533 -2.900
# Time:Cluster[T.1]   7.300    2.837  2.573 0.010   1.739 12.860
# Age                -0.018    0.101 -0.176 0.860  -0.216  0.180
# Education_years    -0.051    0.245 -0.208 0.836  -0.531  0.429
# Gender_2            1.210    2.023  0.598 0.550  -2.755  5.174
# Group Var          37.539
# Group x Time Cov  -19.333
# Time Var           42.661
# ==============================================================
#
# Time p-value (corrected): 0.003
# Cluster p-value (corrected): 0.224
# Interaction p-value (corrected): 0.015
# +---+---------------------+---------------------+----------+--------+----------+---------+--------+
# |   |       group1        |       group2        | meandiff | p-adj  |  lower   |  upper  | reject |
# +---+---------------------+---------------------+----------+--------+----------+---------+--------+
# | 0 | baseline_Subtype I  | baseline_Subtype II | -2.5043  | 0.6705 |  -8.252  | 3.2433  | False  |
# | 1 | baseline_Subtype I  | followup_Subtype I  | -7.2167  | 0.0179 | -13.5264 | -0.9071 |  True  |
# | 2 | baseline_Subtype I  | followup_Subtype II | -2.4215  | 0.6935 | -8.1691  | 3.3262  | False  |
# | 3 | baseline_Subtype II | followup_Subtype I  | -4.7124  | 0.1484 |  -10.46  | 1.0352  | False  |
# | 4 | baseline_Subtype II | followup_Subtype II |  0.0829  |  1.0   | -5.0415  | 5.2072  | False  |
# | 5 | followup_Subtype I  | followup_Subtype II |  4.7953  | 0.1371 | -0.9524  | 10.5429 | False  |
# +---+---------------------+---------------------+----------+--------+----------+---------+--------+
# Cluster: Subtype I, Time: baseline, Mean: 35.44, Std: 8.24
# Cluster: Subtype II, Time: baseline, Mean: 32.94, Std: 10.18
# Cluster: Subtype I, Time: followup, Mean: 28.23, Std: 9.95
# Cluster: Subtype II, Time: followup, Mean: 33.02, Std: 9.46
# ---
# Variable: MONO_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               1.2901
# Min. group size:     2        Log-Likelihood:      -295.1287
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          5.282    0.818  6.455 0.000  3.678  6.886
# Cluster[T.1]       0.381    0.431  0.884 0.377 -0.464  1.225
# Time              -0.264    0.325 -0.814 0.416 -0.900  0.372
# Time:Cluster[T.1]  0.112    0.418  0.267 0.790 -0.708  0.931
# Age                0.031    0.018  1.698 0.089 -0.005  0.067
# Education_years   -0.000    0.045 -0.001 0.999 -0.087  0.087
# Gender_2          -0.604    0.367 -1.644 0.100 -1.324  0.116
# Group Var          1.826
# Group x Time Cov  -0.751
# Time Var           0.687
# ============================================================
#
# Time p-value (corrected): 0.624
# Cluster p-value (corrected): 0.624
# Interaction p-value (corrected): 0.790
# ---
# Variable: PIL_baseline
#              Mixed Linear Model Regression Results
# ================================================================
# Model:               MixedLM    Dependent Variable:    Score
# No. Observations:    156        Method:                REML
# No. Groups:          78         Scale:                 1727.7422
# Min. group size:     2          Log-Likelihood:        -827.4708
# Max. group size:     2          Converged:             Yes
# Mean group size:     2.0
# ----------------------------------------------------------------
#                    Coef.   Std.Err.   z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------
# Intercept          207.498   27.447  7.560 0.000 153.703 261.292
# Cluster[T.1]        -7.145   14.247 -0.502 0.616 -35.070  20.779
# Time               -36.985   12.217 -3.027 0.002 -60.930 -13.041
# Time:Cluster[T.1]   78.956   15.738  5.017 0.000  48.110 109.802
# Age                  0.406    0.619  0.656 0.512  -0.807   1.619
# Education_years     -1.295    1.497 -0.865 0.387  -4.229   1.639
# Gender_2             4.126   12.387  0.333 0.739 -20.152  28.404
# Group Var         1666.378
# Group x Time Cov  -736.017
# Time Var          1171.257
# ================================================================
#
# Time p-value (corrected): 0.004
# Cluster p-value (corrected): 0.616
# Interaction p-value (corrected): 0.000
# +---+---------------------+---------------------+----------+--------+----------+----------+--------+
# |   |       group1        |       group2        | meandiff | p-adj  |  lower   |  upper   | reject |
# +---+---------------------+---------------------+----------+--------+----------+----------+--------+
# | 0 | baseline_Subtype I  | baseline_Subtype II | -3.3375  | 0.9941 | -37.2872 | 30.6121  | False  |
# | 1 | baseline_Subtype I  | followup_Subtype I  | -36.9853 | 0.0526 | -74.2547 |  0.284   | False  |
# | 2 | baseline_Subtype I  | followup_Subtype II |  38.633  | 0.0188 |  4.6834  | 72.5827  |  True  |
# | 3 | baseline_Subtype II | followup_Subtype I  | -33.6478 | 0.053  | -67.5975 |  0.3018  | False  |
# | 4 | baseline_Subtype II | followup_Subtype II | 41.9706  | 0.0024 | 11.7026  | 72.2386  |  True  |
# | 5 | followup_Subtype I  | followup_Subtype II | 75.6184  |  0.0   | 41.6687  | 109.5681 |  True  |
# +---+---------------------+---------------------+----------+--------+----------+----------+--------+
# Cluster: Subtype I, Time: baseline, Mean: 206.86, Std: 61.61
# Cluster: Subtype II, Time: baseline, Mean: 203.52, Std: 54.59
# Cluster: Subtype I, Time: followup, Mean: 169.87, Std: 43.75
# Cluster: Subtype II, Time: followup, Mean: 245.49, Std: 61.96
# ---
# Variable: CRP_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               17.6768
# Min. group size:     2        Log-Likelihood:      -463.5227
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          8.400    1.974  4.256 0.000  4.532 12.269
# Cluster[T.1]       0.339    1.115  0.304 0.761 -1.846  2.524
# Time               0.559    1.296  0.432 0.666 -1.980  3.099
# Time:Cluster[T.1]  0.106    1.669  0.063 0.949 -3.166  3.378
# Age               -0.026    0.044 -0.586 0.558 -0.111  0.060
# Education_years   -0.100    0.106 -0.941 0.346 -0.308  0.108
# Gender_2          -0.749    0.879 -0.852 0.394 -2.473  0.975
# Group Var          3.512
# Group x Time Cov  -6.025
# Time Var          16.706
# ============================================================
#
# Time p-value (corrected): 0.949
# Cluster p-value (corrected): 0.949
# Interaction p-value (corrected): 0.949
# ---
# Variable: NLR_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               1.0136
# Min. group size:     2        Log-Likelihood:      -263.1605
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          1.490    0.587  2.538 0.011  0.340  2.641
# Cluster[T.1]       0.566    0.354  1.601 0.109 -0.127  1.259
# Time               0.695    0.302  2.299 0.021  0.103  1.288
# Time:Cluster[T.1] -0.772    0.389 -1.982 0.047 -1.535 -0.009
# Age               -0.006    0.013 -0.486 0.627 -0.031  0.019
# Education_years    0.042    0.031  1.349 0.177 -0.019  0.102
# Gender_2          -0.180    0.255 -0.704 0.482 -0.680  0.321
# Group Var          1.153
# Group x Time Cov  -0.889
# Time Var           0.806
# ============================================================
#
# Time p-value (corrected): 0.064
# Cluster p-value (corrected): 0.109
# Interaction p-value (corrected): 0.071
# ---
# Variable: PLR_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               5.2237
# Min. group size:     2        Log-Likelihood:      -393.8346
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          5.421    1.355  4.000 0.000  2.765  8.078
# Cluster[T.1]       0.744    0.672  1.107 0.268 -0.573  2.062
# Time               1.044    0.725  1.441 0.150 -0.376  2.464
# Time:Cluster[T.1]  0.043    0.934  0.046 0.964 -1.787  1.872
# Age                0.006    0.031  0.198 0.843 -0.054  0.066
# Education_years    0.049    0.075  0.655 0.512 -0.097  0.195
# Gender_2          -0.126    0.616 -0.204 0.838 -1.332  1.081
# Group Var          2.231
# Group x Time Cov  -0.877
# Time Var           5.832
# ============================================================
#
# Time p-value (corrected): 0.402
# Cluster p-value (corrected): 0.402
# Interaction p-value (corrected): 0.964
# ---
# Variable: MLR_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM   Dependent Variable:   Score
# No. Observations:    156       Method:               REML
# No. Groups:          78        Scale:                0.0129
# Min. group size:     2         Log-Likelihood:       65.5333
# Max. group size:     2         Converged:            Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          0.096    0.063  1.528 0.127 -0.027  0.218
# Cluster[T.1]       0.064    0.039  1.630 0.103 -0.013  0.140
# Time               0.059    0.035  1.712 0.087 -0.009  0.128
# Time:Cluster[T.1] -0.089    0.045 -1.995 0.046 -0.177 -0.002
# Age                0.002    0.001  1.314 0.189 -0.001  0.004
# Education_years    0.004    0.003  1.104 0.270 -0.003  0.010
# Gender_2          -0.034    0.027 -1.263 0.206 -0.087  0.019
# Group Var          0.014
# Group x Time Cov  -0.012
# Time Var           0.012
# ============================================================
#
# Time p-value (corrected): 0.103
# Cluster p-value (corrected): 0.103
# Interaction p-value (corrected): 0.103
# ---
# Variable: SIII_baseline
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM    Dependent Variable:    Score
# No. Observations:      156        Method:                REML
# No. Groups:            78         Scale:                 29479.0416
# Min. group size:       2          Log-Likelihood:        -1033.3293
# Max. group size:       2          Converged:             Yes
# Mean group size:       2.0
# -------------------------------------------------------------------
#                     Coef.    Std.Err.   z    P>|z|  [0.025   0.975]
# -------------------------------------------------------------------
# Intercept            322.954  103.703  3.114 0.002  119.699 526.209
# Cluster[T.1]          73.685   54.795  1.345 0.179  -33.711 181.080
# Time                  53.387   51.301  1.041 0.298  -47.161 153.935
# Time:Cluster[T.1]     29.511   66.088  0.447 0.655 -100.019 159.042
# Age                   -0.583    2.326 -0.251 0.802   -5.142   3.976
# Education_years        5.490    5.635  0.974 0.330   -5.553  16.534
# Gender_2             -42.371   46.766 -0.906 0.365 -134.031  49.288
# Group Var          20950.173
# Group x Time Cov  -11806.775
# Time Var           22626.927
# ===================================================================
#
# Time p-value (corrected): 0.447
# Cluster p-value (corrected): 0.447
# Interaction p-value (corrected): 0.655
# ---
# Variable: ASTALT_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               0.1386
# Min. group size:     2        Log-Likelihood:      -110.5044
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          1.074    0.203  5.299 0.000  0.677  1.471
# Cluster[T.1]       0.158    0.117  1.355 0.175 -0.070  0.386
# Time               0.010    0.111  0.093 0.926 -0.208  0.229
# Time:Cluster[T.1] -0.160    0.143 -1.117 0.264 -0.441  0.121
# Age               -0.000    0.004 -0.028 0.977 -0.009  0.009
# Education_years   -0.015    0.011 -1.429 0.153 -0.037  0.006
# Gender_2           0.070    0.089  0.784 0.433 -0.105  0.245
# Group Var          0.094
# Group x Time Cov  -0.080
# Time Var           0.107
# ============================================================
#
# Time p-value (corrected): 0.926
# Cluster p-value (corrected): 0.396
# Interaction p-value (corrected): 0.396
# ---
# Variable: LDH_baseline
#              Mixed Linear Model Regression Results
# ================================================================
# Model:               MixedLM    Dependent Variable:    Score
# No. Observations:    156        Method:                REML
# No. Groups:          78         Scale:                 337.7400
# Min. group size:     2          Log-Likelihood:        -681.7060
# Max. group size:     2          Converged:             Yes
# Mean group size:     2.0
# ----------------------------------------------------------------
#                    Coef.   Std.Err.   z    P>|z|  [0.025  0.975]
# ----------------------------------------------------------------
# Intercept          138.909    8.573 16.203 0.000 122.106 155.711
# Cluster[T.1]         5.663    5.089  1.113 0.266  -4.311  15.636
# Time               -18.966    5.654 -3.354 0.001 -30.048  -7.883
# Time:Cluster[T.1]   26.649    7.284  3.658 0.000  12.372  40.925
# Age                  0.144    0.187  0.769 0.442  -0.223   0.510
# Education_years      0.345    0.456  0.757 0.449  -0.548   1.239
# Gender_2             1.999    3.770  0.530 0.596  -5.390   9.388
# Group Var          108.740
# Group x Time Cov  -165.570
# Time Var           315.640
# ================================================================
#
# Time p-value (corrected): 0.001
# Cluster p-value (corrected): 0.266
# Interaction p-value (corrected): 0.001
# +---+---------------------+---------------------+----------+--------+----------+----------+--------+
# |   |       group1        |       group2        | meandiff | p-adj  |  lower   |  upper   | reject |
# +---+---------------------+---------------------+----------+--------+----------+----------+--------+
# | 0 | baseline_Subtype I  | baseline_Subtype II |  5.5512  | 0.6614 | -7.0264  | 18.1287  | False  |
# | 1 | baseline_Subtype I  | followup_Subtype I  | -18.9656 | 0.0027 | -32.773  | -5.1582  |  True  |
# | 2 | baseline_Subtype I  | followup_Subtype II | 13.2341  | 0.035  |  0.6566  | 25.8117  |  True  |
# | 3 | baseline_Subtype II | followup_Subtype I  | -24.5167 |  0.0   | -37.0943 | -11.9392 |  True  |
# | 4 | baseline_Subtype II | followup_Subtype II |  7.683   | 0.287  | -3.5306  | 18.8966  | False  |
# | 5 | followup_Subtype I  | followup_Subtype II | 32.1997  |  0.0   | 19.6222  | 44.7772  |  True  |
# +---+---------------------+---------------------+----------+--------+----------+----------+--------+
# Cluster: Subtype I, Time: baseline, Mean: 148.37, Std: 20.86
# Cluster: Subtype II, Time: baseline, Mean: 153.92, Std: 21.40
# Cluster: Subtype I, Time: followup, Mean: 129.40, Std: 21.18
# Cluster: Subtype II, Time: followup, Mean: 161.60, Std: 20.31
# ---

# %%
def plot_interaction(df_long, var_name):
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    # 设置整体风格，确保图表清晰且专业，增强图表对比度
    sns.set(style="whitegrid", font_scale=1.2)
    plt.figure(figsize=(4.5,4.5))  # 提高分辨率以满足高水平出版要求
    
    # 将群组标签映射到新的名称
    df_long['Cluster'] = df_long['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
    
    # 使用具有色盲友好特性的调色板
    palette = {
        "Subtype I": "#59A14F",  # Green
        "Subtype II": "#E15759",  # Red
}
    # 绘制带误差条的交互作用图，并调整透明度以突出关键趋势线
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette=palette, 
                 marker='s', linewidth=3.5, alpha=0.85, markersize=12)
    
    # 为每个亚组设置不同的颜色，并在X轴上错开显示
    offset = {'Subtype I': -0.1, 'Subtype II': 0.1}  # 设置X轴偏移量
    for cluster, color in zip(['Subtype I', 'Subtype II'], ["#59A14F", "#E15759"]):
        grp = df_long[df_long['Cluster'] == cluster]
        for _, subject_grp in grp.groupby('Subject'):
            x_positions = subject_grp['Time'] + offset[cluster]  # 添加偏移量
            plt.plot(x_positions, subject_grp['Score'], marker='o', color=color, alpha=0.4, linewidth=1.0, markersize=4)

    # 图表标题和标签，使用更加清晰的字体大小和粗细
    plt.title(f'Lymphocytes (%)', fontsize=14, fontweight='bold', pad=10)

    plt.xlabel('Time', fontsize=14, fontweight='bold')
    plt.ylabel('Score', fontsize=14, fontweight='bold')
    plt.xticks([0.1, 0.9], ['Baseline', 'Follow-up'], fontsize=12)
    
    # 调整图例的位置和标签，设置图例框架和位置
    plt.legend(loc='upper left', fontsize=11, frameon=False, ncol=2, bbox_to_anchor=(0.01, -0.2))
    # 设置外边框线条黑色加粗
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)
        spine.set_linestyle('--')
    # 设置网格线，提升图表的专业感，适度降低透明度
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()  # 自动调整布局，确保图表元素不重叠
    plt.savefig(f'image/{var_name}.jpg', dpi=1200, bbox_inches='tight')
    plt.show()
# 调用示例：绘制指定变量的交互作用图
var_name = 'LYMPH_baseline'
plot_interaction(results[var_name]['df_long'], var_name)

# %%
def plot_interaction(df_long, var_name):
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    # 设置整体风格，确保图表清晰且专业，增强图表对比度
    sns.set(style="whitegrid", font_scale=1.2)
    plt.figure(figsize=(4.5,4.5))  # 提高分辨率以满足高水平出版要求
    
    # 将群组标签映射到新的名称
    df_long['Cluster'] = df_long['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
    
    # 使用具有色盲友好特性的调色板
    palette = {
        "Subtype I": "#59A14F",  # Green
        "Subtype II": "#E15759",  # Red
}
    # 绘制带误差条的交互作用图，并调整透明度以突出关键趋势线
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette=palette, 
                 marker='s', linewidth=3.5, alpha=0.85, markersize=12)
    
    # 为每个亚组设置不同的颜色，并在X轴上错开显示
    offset = {'Subtype I': -0.1, 'Subtype II': 0.1}  # 设置X轴偏移量
    for cluster, color in zip(['Subtype I', 'Subtype II'], ["#59A14F", "#E15759"]):
        grp = df_long[df_long['Cluster'] == cluster]
        for _, subject_grp in grp.groupby('Subject'):
            x_positions = subject_grp['Time'] + offset[cluster]  # 添加偏移量
            plt.plot(x_positions, subject_grp['Score'], marker='o', color=color, alpha=0.4, linewidth=1.0, markersize=4)

    # 图表标题和标签，使用更加清晰的字体大小和粗细
    plt.title(f'Platelet-Lymphocyte Ratio', fontsize=14, fontweight='bold', pad=10)

    plt.xlabel('Time', fontsize=14, fontweight='bold')
    plt.ylabel('Score', fontsize=14, fontweight='bold')
    plt.xticks([0.1, 0.9], ['Baseline', 'Follow-up'], fontsize=12)
    
    # 调整图例的位置和标签，设置图例框架和位置
    plt.legend(loc='upper left', fontsize=11, frameon=False, ncol=2, bbox_to_anchor=(0.01, -0.2))
    # 设置外边框线条黑色加粗
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)
        spine.set_linestyle('--')
    # 设置网格线，提升图表的专业感，适度降低透明度
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()  # 自动调整布局，确保图表元素不重叠
    plt.savefig(f'image/{var_name}.jpg', dpi=1200, bbox_inches='tight')
    plt.show()
# 调用示例：绘制指定变量的交互作用图
var_name = 'PIL_baseline'
plot_interaction(results[var_name]['df_long'], var_name)

# %%
def plot_interaction(df_long, var_name):
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    # 设置整体风格，确保图表清晰且专业，增强图表对比度
    sns.set(style="whitegrid", font_scale=1.2)
    plt.figure(figsize=(4.5,4.5))  # 提高分辨率以满足高水平出版要求
    
    # 将群组标签映射到新的名称
    df_long['Cluster'] = df_long['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
    
    # 使用具有色盲友好特性的调色板
    palette = {
        "Subtype I": "#59A14F",  # Green
        "Subtype II": "#E15759",  # Red
}
    # 绘制带误差条的交互作用图，并调整透明度以突出关键趋势线
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette=palette, 
                 marker='s', linewidth=3.5, alpha=0.85, markersize=12)
    
    # 为每个亚组设置不同的颜色，并在X轴上错开显示
    offset = {'Subtype I': -0.1, 'Subtype II': 0.1}  # 设置X轴偏移量
    for cluster, color in zip(['Subtype I', 'Subtype II'], ["#59A14F", "#E15759"]):
        grp = df_long[df_long['Cluster'] == cluster]
        for _, subject_grp in grp.groupby('Subject'):
            x_positions = subject_grp['Time'] + offset[cluster]  # 添加偏移量
            plt.plot(x_positions, subject_grp['Score'], marker='o', color=color, alpha=0.4, linewidth=1.0, markersize=4)

    # 图表标题和标签，使用更加清晰的字体大小和粗细
    plt.title(f'Lactate Dehydrogenase (U/L)', fontsize=14, fontweight='bold', pad=10)

    plt.xlabel('Time', fontsize=14, fontweight='bold')
    plt.ylabel('Score', fontsize=14, fontweight='bold')
    plt.xticks([0.1, 0.9], ['Baseline', 'Follow-up'], fontsize=12)
    
    # 调整图例的位置和标签，设置图例框架和位置
    plt.legend(loc='upper left', fontsize=11, frameon=False, ncol=2, bbox_to_anchor=(0.01, -0.2))
    # 设置外边框线条黑色加粗
    ax = plt.gca()
    for spine in ax.spines.values():
        spine.set_edgecolor('black')
        spine.set_linewidth(1)
        spine.set_linestyle('--')
    # 设置网格线，提升图表的专业感，适度降低透明度
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()  # 自动调整布局，确保图表元素不重叠
    plt.savefig(f'image/{var_name}.jpg', dpi=1200, bbox_inches='tight')
    plt.show()
# 调用示例：绘制指定变量的交互作用图
var_name = 'LDH_baseline'
plot_interaction(results[var_name]['df_long'], var_name)

# %% [markdown]
# ----

# %% [markdown]
# ## 免疫

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import warnings

warnings.filterwarnings('ignore')
# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet2')

# 删除 'Cluster' 列中等于 3 的行
data_cleaned = data[data['Cluster'] != 3]


# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ("CK_baseline", "CK_followup"),
    ("TG_baseline", "TG_followup"),
    ("CHOL_baseline", "CHOL_followup"),
    ("HDLC_baseline", "HDLC_followup"),
    ("LDLC_baseline", "LDLC_followup")
]

# 确保所有列名一致
required_columns = [
    'Cluster', 'Age', 
    'Education_years','Gender'
]

missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"The following required columns are missing from the data: {missing_columns}")

# 创建字典以存储结果
results = {}

# 对每个变量进行单因素协方差分析
def perform_ancova_analysis(symptom_var, time_point):
    # 选择特定时间点的数据
    if time_point == "baseline":
        df = data[[symptom_var] + required_columns]
    else:
        df = data[[symptom_var.replace("baseline", "followup")] + required_columns]
        df.columns = [col.replace("followup", "baseline") for col in df.columns]
    
    # 构建ANCOVA模型公式
    formula = (f"{symptom_var} ~ Cluster + Age + "
               "Education_years + " +
               " + ".join([col for col in required_columns if col != 'Cluster']))
    
    # 拟合模型
    model = ols(formula, data=df).fit()
    
    # 进行方差分析
    ancova_results = anova_lm(model, typ=2)
    
    # 对p值进行FDR BH校正
    p_values = ancova_results['PR(>F)'].values
    p_values_corrected = multipletests(p_values, method='fdr_bh')[1]
    ancova_results['PR(>F)_corrected'] = p_values_corrected
    
    # 返回结果
    return {
        'ANCOVA_summary': ancova_results,
        'Model_summary': model.summary()
    }

# 对每个变量在基线和随访时进行分析并存储结果
for baseline_var, followup_var in variables:
    # 基线分析
    results[baseline_var] = perform_ancova_analysis(baseline_var, "baseline")
    # 随访分析
    results[followup_var] = perform_ancova_analysis(baseline_var, "followup")

# 输出结果
for var, result in results.items():
    print(f"Variable: {var}")
    print(result['ANCOVA_summary'])
    print(result['Model_summary'])
    print("---")
# Out:
# Variable: CK_baseline
#                         sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            3443.726097   1.0  0.829955  0.364989               NaN
# Age                2221.271556   1.0  0.535338  0.466483               NaN
# Education_years     344.248783   1.0  0.082966  0.774054               NaN
# Gender              290.657941   1.0  0.070050  0.791936               NaN
# Residual         336092.598454  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            CK_baseline   R-squared:                       0.023
# Model:                            OLS   Adj. R-squared:                 -0.026
# Method:                 Least Squares   F-statistic:                    0.4694
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.758
# Time:                        18:59:50   Log-Likelihood:                -477.67
# No. Observations:                  86   AIC:                             965.3
# Df Residuals:                      81   BIC:                             977.6
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         113.4006     34.153      3.320      0.001      45.447     181.354
# Cluster            -7.7114      8.465     -0.911      0.365     -24.553       9.131
# Age                -0.5910      0.808     -0.732      0.466      -2.198       1.016
# Education_years     0.5274      1.831      0.288      0.774      -3.116       4.170
# Gender             -4.1092     15.526     -0.265      0.792     -35.001      26.782
# ==============================================================================
# Omnibus:                       95.056   Durbin-Watson:                   2.216
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1199.025
# Skew:                           3.514   Prob(JB):                    4.32e-261
# Kurtosis:                      19.888   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: CK_followup
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            220.518970   1.0  0.193826  0.660924               NaN
# Age                 60.582463   1.0  0.053249  0.818085               NaN
# Education_years      0.108874   1.0  0.000096  0.992219               NaN
# Gender              81.386521   1.0  0.071535  0.789795               NaN
# Residual         92154.962219  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            CK_baseline   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.044
# Method:                 Least Squares   F-statistic:                    0.1055
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.980
# Time:                        18:59:50   Log-Likelihood:                -422.03
# No. Observations:                  86   AIC:                             854.1
# Df Residuals:                      81   BIC:                             866.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          82.2991     17.884      4.602      0.000      46.716     117.882
# Cluster            -1.9514      4.432     -0.440      0.661     -10.770       6.868
# Age                -0.0976      0.423     -0.231      0.818      -0.939       0.744
# Education_years     0.0094      0.959      0.010      0.992      -1.898       1.917
# Gender             -2.1744      8.130     -0.267      0.790     -18.350      14.002
# ==============================================================================
# Omnibus:                       11.143   Durbin-Watson:                   2.786
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.365
# Skew:                           0.798   Prob(JB):                      0.00341
# Kurtosis:                       3.790   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: TG_baseline
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           0.014971   1.0  0.029112  0.864947               NaN
# Age               0.020059   1.0  0.039006  0.843931               NaN
# Education_years   0.903426   1.0  1.756786  0.188752               NaN
# Gender            2.932529   1.0  5.702545  0.019268               NaN
# Residual         41.654176  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TG_baseline   R-squared:                       0.080
# Model:                            OLS   Adj. R-squared:                  0.034
# Method:                 Least Squares   F-statistic:                     1.750
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.147
# Time:                        18:59:50   Log-Likelihood:                -90.856
# No. Observations:                  86   AIC:                             191.7
# Df Residuals:                      81   BIC:                             204.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.8671      0.380      4.911      0.000       1.111       2.624
# Cluster            -0.0161      0.094     -0.171      0.865      -0.204       0.171
# Age                -0.0018      0.009     -0.197      0.844      -0.020       0.016
# Education_years     0.0270      0.020      1.325      0.189      -0.014       0.068
# Gender             -0.4128      0.173     -2.388      0.019      -0.757      -0.069
# ==============================================================================
# Omnibus:                       18.481   Durbin-Watson:                   1.237
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               23.162
# Skew:                           1.045   Prob(JB):                     9.34e-06
# Kurtosis:                       4.447   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: TG_followup
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           0.183401   1.0  0.292060  0.590387               NaN
# Age               0.396114   1.0  0.630799  0.429383               NaN
# Education_years   0.056185   1.0  0.089473  0.765615               NaN
# Gender            2.700154   1.0  4.299911  0.041292               NaN
# Residual         50.864432  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            TG_baseline   R-squared:                       0.071
# Model:                            OLS   Adj. R-squared:                  0.025
# Method:                 Least Squares   F-statistic:                     1.554
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.195
# Time:                        18:59:50   Log-Likelihood:                -99.446
# No. Observations:                  86   AIC:                             208.9
# Df Residuals:                      81   BIC:                             221.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           2.2756      0.420      5.416      0.000       1.440       3.112
# Cluster             0.0563      0.104      0.540      0.590      -0.151       0.263
# Age                -0.0079      0.010     -0.794      0.429      -0.028       0.012
# Education_years     0.0067      0.023      0.299      0.766      -0.038       0.052
# Gender             -0.3961      0.191     -2.074      0.041      -0.776      -0.016
# ==============================================================================
# Omnibus:                        5.951   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.051   Jarque-Bera (JB):                5.830
# Skew:                           0.638   Prob(JB):                       0.0542
# Kurtosis:                       2.986   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: CHOL_baseline
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           1.915427   1.0  2.097338  0.151416               NaN
# Age               0.297489   1.0  0.325742  0.569757               NaN
# Education_years   0.017165   1.0  0.018796  0.891294               NaN
# Gender            0.683475   1.0  0.748386  0.389543               NaN
# Residual         73.974540  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          CHOL_baseline   R-squared:                       0.034
# Model:                            OLS   Adj. R-squared:                 -0.013
# Method:                 Least Squares   F-statistic:                    0.7234
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.578
# Time:                        18:59:50   Log-Likelihood:                -115.55
# No. Observations:                  86   AIC:                             241.1
# Df Residuals:                      81   BIC:                             253.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           4.1278      0.507      8.147      0.000       3.120       5.136
# Cluster            -0.1819      0.126     -1.448      0.151      -0.432       0.068
# Age                -0.0068      0.012     -0.571      0.570      -0.031       0.017
# Education_years    -0.0037      0.027     -0.137      0.891      -0.058       0.050
# Gender              0.1993      0.230      0.865      0.390      -0.259       0.658
# ==============================================================================
# Omnibus:                        8.880   Durbin-Watson:                   1.724
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.531
# Skew:                           0.717   Prob(JB):                       0.0140
# Kurtosis:                       3.570   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: CHOL_followup
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           0.041121   1.0  0.047467  0.828079               NaN
# Age               0.262594   1.0  0.303120  0.583448               NaN
# Education_years   0.000844   1.0  0.000975  0.975169               NaN
# Gender            0.535640   1.0  0.618307  0.433972               NaN
# Residual         70.170436  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          CHOL_baseline   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.038
# Method:                 Least Squares   F-statistic:                    0.2159
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.929
# Time:                        18:59:50   Log-Likelihood:                -113.28
# No. Observations:                  86   AIC:                             236.6
# Df Residuals:                      81   BIC:                             248.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           4.0342      0.493      8.175      0.000       3.052       5.016
# Cluster            -0.0266      0.122     -0.218      0.828      -0.270       0.217
# Age                -0.0064      0.012     -0.551      0.583      -0.030       0.017
# Education_years     0.0008      0.026      0.031      0.975      -0.052       0.053
# Gender              0.1764      0.224      0.786      0.434      -0.270       0.623
# ==============================================================================
# Omnibus:                        2.725   Durbin-Watson:                   2.081
# Prob(Omnibus):                  0.256   Jarque-Bera (JB):                2.706
# Skew:                           0.412   Prob(JB):                        0.258
# Kurtosis:                       2.725   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: HDLC_baseline
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.073117   1.0  1.202545  0.276063               NaN
# Age              0.066298   1.0  1.090402  0.299489               NaN
# Education_years  0.111001   1.0  1.825626  0.180407               NaN
# Gender           0.149860   1.0  2.464734  0.120326               NaN
# Residual         4.924936  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HDLC_baseline   R-squared:                       0.086
# Model:                            OLS   Adj. R-squared:                  0.041
# Method:                 Least Squares   F-statistic:                     1.904
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.118
# Time:                        18:59:50   Log-Likelihood:                0.95283
# No. Observations:                  86   AIC:                             8.094
# Df Residuals:                      81   BIC:                             20.37
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.9743      0.131      7.452      0.000       0.714       1.234
# Cluster             0.0355      0.032      1.097      0.276      -0.029       0.100
# Age                 0.0032      0.003      1.044      0.299      -0.003       0.009
# Education_years    -0.0095      0.007     -1.351      0.180      -0.023       0.004
# Gender              0.0933      0.059      1.570      0.120      -0.025       0.212
# ==============================================================================
# Omnibus:                        7.165   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                7.224
# Skew:                           0.710   Prob(JB):                       0.0270
# Kurtosis:                       2.994   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: HDLC_followup
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.022543   1.0  0.275631  0.601013               NaN
# Age              0.037599   1.0  0.459711  0.499691               NaN
# Education_years  0.283631   1.0  3.467881  0.066198               NaN
# Gender           0.167323   1.0  2.045820  0.156471               NaN
# Residual         6.624824  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          HDLC_baseline   R-squared:                       0.059
# Model:                            OLS   Adj. R-squared:                  0.013
# Method:                 Least Squares   F-statistic:                     1.278
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.285
# Time:                        18:59:50   Log-Likelihood:                -11.797
# No. Observations:                  86   AIC:                             33.59
# Df Residuals:                      81   BIC:                             45.87
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.1499      0.152      7.584      0.000       0.848       1.452
# Cluster            -0.0197      0.038     -0.525      0.601      -0.095       0.055
# Age                 0.0024      0.004      0.678      0.500      -0.005       0.010
# Education_years    -0.0151      0.008     -1.862      0.066      -0.031       0.001
# Gender              0.0986      0.069      1.430      0.156      -0.039       0.236
# ==============================================================================
# Omnibus:                        9.054   Durbin-Watson:                   2.265
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.572
# Skew:                           0.817   Prob(JB):                      0.00835
# Kurtosis:                       2.990   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: LDLC_baseline
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           1.478725   1.0  2.498620  0.117843               NaN
# Age               0.577442   1.0  0.975711  0.326202               NaN
# Education_years   0.047214   1.0  0.079778  0.778319               NaN
# Gender            0.273209   1.0  0.461644  0.498794               NaN
# Residual         47.937153  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          LDLC_baseline   R-squared:                       0.049
# Model:                            OLS   Adj. R-squared:                  0.002
# Method:                 Least Squares   F-statistic:                     1.034
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.395
# Time:                        18:59:50   Log-Likelihood:                -96.897
# No. Observations:                  86   AIC:                             203.8
# Df Residuals:                      81   BIC:                             216.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           2.7199      0.408      6.668      0.000       1.908       3.531
# Cluster            -0.1598      0.101     -1.581      0.118      -0.361       0.041
# Age                -0.0095      0.010     -0.988      0.326      -0.029       0.010
# Education_years     0.0062      0.022      0.282      0.778      -0.037       0.050
# Gender              0.1260      0.185      0.679      0.499      -0.243       0.495
# ==============================================================================
# Omnibus:                        9.712   Durbin-Watson:                   1.661
# Prob(Omnibus):                  0.008   Jarque-Bera (JB):                9.530
# Skew:                           0.754   Prob(JB):                      0.00852
# Kurtosis:                       3.619   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: LDLC_followup
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           0.032356   1.0  0.053423  0.817794               NaN
# Age               0.346090   1.0  0.571436  0.451882               NaN
# Education_years   0.266266   1.0  0.439638  0.509180               NaN
# Gender            0.302434   1.0  0.499355  0.481811               NaN
# Residual         49.057582  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          LDLC_baseline   R-squared:                       0.021
# Model:                            OLS   Adj. R-squared:                 -0.027
# Method:                 Least Squares   F-statistic:                    0.4334
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.784
# Time:                        18:59:50   Log-Likelihood:                -97.891
# No. Observations:                  86   AIC:                             205.8
# Df Residuals:                      81   BIC:                             218.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           2.4885      0.413      6.031      0.000       1.668       3.310
# Cluster            -0.0236      0.102     -0.231      0.818      -0.227       0.180
# Age                -0.0074      0.010     -0.756      0.452      -0.027       0.012
# Education_years     0.0147      0.022      0.663      0.509      -0.029       0.059
# Gender              0.1326      0.188      0.707      0.482      -0.241       0.506
# ==============================================================================
# Omnibus:                        0.766   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.682   Jarque-Bera (JB):                0.704
# Skew:                           0.215   Prob(JB):                        0.703
# Kurtosis:                       2.895   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats.multitest import multipletests
import warnings

warnings.filterwarnings('ignore')
# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet2')

# 删除 'Cluster' 列中等于 3 的行
data_cleaned = data[data['Cluster'] != 3]

# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ("CK_baseline", "CK_followup"),
    ("TG_baseline", "TG_followup"),
    ("CHOL_baseline", "CHOL_followup"),
    ("HDLC_baseline", "HDLC_followup"),
    ("LDLC_baseline", "LDLC_followup")
]

# 创建字典以存储结果
results = {}

# 定义函数进行配对t检验
def perform_paired_ttest(group, baseline_var, followup_var):
    baseline_scores = data[data['Cluster'] == group][baseline_var]
    followup_scores = data[data['Cluster'] == group][followup_var]
    
    # 进行配对t检验
    t_stat, p_value = stats.ttest_rel(baseline_scores, followup_scores)
    
    return p_value

# 对每个变量在两个亚组进行分析并存储结果
for baseline_var, followup_var in variables:
    p_values_group1 = perform_paired_ttest(0, baseline_var, followup_var)
    p_values_group2 = perform_paired_ttest(1, baseline_var, followup_var)
    
    # 将结果存储在字典中
    results[(baseline_var, 'Group1')] = p_values_group1
    results[(baseline_var, 'Group2')] = p_values_group2

# 将p值进行FDR BH校正
p_values = list(results.values())
p_values_corrected = multipletests(p_values, method='fdr_bh')[1]

# 更新结果字典
corrected_results = {}
for i, key in enumerate(results.keys()):
    corrected_results[key] = p_values_corrected[i]

# 输出结果
for var in variables:
    print(f"Variable: {var[0]}")
    print(f"Group 1 (Subtype I) p-value (corrected): {corrected_results[(var[0], 'Group1')]:.4f}")
    print(f"Group 2 (Subtype II) p-value (corrected): {corrected_results[(var[0], 'Group2')]:.4f}")
    print("---")
# Out:
# Variable: CK_baseline
# Group 1 (Subtype I) p-value (corrected): 0.4602
# Group 2 (Subtype II) p-value (corrected): 0.5974
# ---
# Variable: TG_baseline
# Group 1 (Subtype I) p-value (corrected): 0.8164
# Group 2 (Subtype II) p-value (corrected): 0.5974
# ---
# Variable: CHOL_baseline
# Group 1 (Subtype I) p-value (corrected): 0.5974
# Group 2 (Subtype II) p-value (corrected): 0.4602
# ---
# Variable: HDLC_baseline
# Group 1 (Subtype I) p-value (corrected): 0.4602
# Group 2 (Subtype II) p-value (corrected): 0.6117
# ---
# Variable: LDLC_baseline
# Group 1 (Subtype I) p-value (corrected): 0.5974
# Group 2 (Subtype II) p-value (corrected): 0.4602
# ---

# %% [markdown]
# ## 代谢

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import warnings

warnings.filterwarnings('ignore')
# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet2')

# 删除 'Cluster' 列中等于 3 的行
data_cleaned = data[data['Cluster'] != 3]


# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ( "WBC_baseline", "WBC_followup"),
    ("NEUT_baseline", "NEUT_followup"),
    ("LYMPH_baseline", "LYMPH_followup"),
    ("MONO_baseline", "MONO_followup"),
    ("PIL_baseline", "PIL_followup"),
    ("CRP_baseline", "CRP_followup"),
    ("NLR_baseline", "NLR_followup"),
    ("PLR_baseline", "PLR_followup"),
    ("MLR_baseline", "MLR_followup"),
    ("SIII_baseline", "SIII_followup"),
    ("ASTALT_baseline", "ASTALT_followup"),
    ("LDH_baseline", "LDH_followup"),
]

# 确保所有列名一致
required_columns = [
    'Cluster', 'Age', 
    'Education_years','Gender'
]

missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"The following required columns are missing from the data: {missing_columns}")

# 创建字典以存储结果
results = {}

# 对每个变量进行单因素协方差分析
def perform_ancova_analysis(symptom_var, time_point):
    # 选择特定时间点的数据
    if time_point == "baseline":
        df = data[[symptom_var] + required_columns]
    else:
        df = data[[symptom_var.replace("baseline", "followup")] + required_columns]
        df.columns = [col.replace("followup", "baseline") for col in df.columns]
    
    # 构建ANCOVA模型公式
    formula = (f"{symptom_var} ~ Cluster + Age + "
               "Education_years + " +
               " + ".join([col for col in required_columns if col != 'Cluster']))
    
    # 拟合模型
    model = ols(formula, data=df).fit()
    
    # 进行方差分析
    ancova_results = anova_lm(model, typ=2)
    
    # 对p值进行FDR BH校正
    p_values = ancova_results['PR(>F)'].values
    p_values_corrected = multipletests(p_values, method='fdr_bh')[1]
    ancova_results['PR(>F)_corrected'] = p_values_corrected
    
    # 返回结果
    return {
        'ANCOVA_summary': ancova_results,
        'Model_summary': model.summary()
    }

# 对每个变量在基线和随访时进行分析并存储结果
for baseline_var, followup_var in variables:
    # 基线分析
    results[baseline_var] = perform_ancova_analysis(baseline_var, "baseline")
    # 随访分析
    results[followup_var] = perform_ancova_analysis(baseline_var, "followup")

# 输出结果
for var, result in results.items():
    print(f"Variable: {var}")
    print(result['ANCOVA_summary'])
    print(result['Model_summary'])
    print("---")
# Out:
# Variable: WBC_baseline
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            0.118169   1.0  0.052763  0.818903               NaN
# Age                0.046321   1.0  0.020683  0.886004               NaN
# Education_years    2.729066   1.0  1.218535  0.272917               NaN
# Gender             0.186629   1.0  0.083331  0.773571               NaN
# Residual         181.409952  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           WBC_baseline   R-squared:                       0.015
# Model:                            OLS   Adj. R-squared:                 -0.034
# Method:                 Least Squares   F-statistic:                    0.3098
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.871
# Time:                        18:59:50   Log-Likelihood:                -154.12
# No. Observations:                  86   AIC:                             318.2
# Df Residuals:                      81   BIC:                             330.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.1094      0.793      7.700      0.000       4.531       7.688
# Cluster            -0.0452      0.197     -0.230      0.819      -0.436       0.346
# Age                 0.0027      0.019      0.144      0.886      -0.035       0.040
# Education_years    -0.0470      0.043     -1.104      0.273      -0.132       0.038
# Gender              0.1041      0.361      0.289      0.774      -0.614       0.822
# ==============================================================================
# Omnibus:                        6.177   Durbin-Watson:                   1.941
# Prob(Omnibus):                  0.046   Jarque-Bera (JB):                5.691
# Skew:                           0.488   Prob(JB):                       0.0581
# Kurtosis:                       3.798   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: WBC_followup
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            3.181661   1.0  1.153567  0.285993               NaN
# Age                3.717417   1.0  1.347815  0.249070               NaN
# Education_years    2.517360   1.0  0.912713  0.342238               NaN
# Gender             2.754300   1.0  0.998620  0.320621               NaN
# Residual         223.406564  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           WBC_baseline   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.005
# Method:                 Least Squares   F-statistic:                     1.115
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.355
# Time:                        18:59:50   Log-Likelihood:                -163.08
# No. Observations:                  86   AIC:                             336.2
# Df Residuals:                      81   BIC:                             348.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.7533      0.881      7.670      0.000       5.001       8.505
# Cluster            -0.2344      0.218     -1.074      0.286      -0.669       0.200
# Age                 0.0242      0.021      1.161      0.249      -0.017       0.066
# Education_years    -0.0451      0.047     -0.955      0.342      -0.139       0.049
# Gender             -0.4000      0.400     -0.999      0.321      -1.196       0.396
# ==============================================================================
# Omnibus:                        4.566   Durbin-Watson:                   2.293
# Prob(Omnibus):                  0.102   Jarque-Bera (JB):                3.865
# Skew:                           0.492   Prob(JB):                        0.145
# Kurtosis:                       3.333   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: NEUT_baseline
#                       sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            81.390385   1.0  0.844309  0.360895               NaN
# Age                 2.202895   1.0  0.022852  0.880219               NaN
# Education_years    87.884872   1.0  0.911680  0.342510               NaN
# Gender              0.559047   1.0  0.005799  0.939485               NaN
# Residual         7808.300175  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          NEUT_baseline   R-squared:                       0.026
# Model:                            OLS   Adj. R-squared:                 -0.022
# Method:                 Least Squares   F-statistic:                    0.5325
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.712
# Time:                        18:59:50   Log-Likelihood:                -315.90
# No. Observations:                  86   AIC:                             641.8
# Df Residuals:                      81   BIC:                             654.1
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          59.4530      5.206     11.421      0.000      49.095      69.811
# Cluster             1.1855      1.290      0.919      0.361      -1.382       3.753
# Age                -0.0186      0.123     -0.151      0.880      -0.264       0.226
# Education_years    -0.2665      0.279     -0.955      0.343      -0.822       0.289
# Gender              0.1802      2.366      0.076      0.939      -4.528       4.889
# ==============================================================================
# Omnibus:                        1.136   Durbin-Watson:                   2.201
# Prob(Omnibus):                  0.567   Jarque-Bera (JB):                0.605
# Skew:                          -0.127   Prob(JB):                        0.739
# Kurtosis:                       3.323   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: NEUT_followup
#                       sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            28.603539   1.0  0.273081  0.602699               NaN
# Age               115.409588   1.0  1.101829  0.296987               NaN
# Education_years     7.835989   1.0  0.074811  0.785153               NaN
# Gender              0.567322   1.0  0.005416  0.941514               NaN
# Residual         8484.232803  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          NEUT_baseline   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                 -0.029
# Method:                 Least Squares   F-statistic:                    0.3962
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.811
# Time:                        18:59:50   Log-Likelihood:                -319.47
# No. Observations:                  86   AIC:                             648.9
# Df Residuals:                      81   BIC:                             661.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          65.1117      5.426     11.999      0.000      54.315      75.908
# Cluster             0.7028      1.345      0.523      0.603      -1.973       3.379
# Age                -0.1347      0.128     -1.050      0.297      -0.390       0.121
# Education_years    -0.0796      0.291     -0.274      0.785      -0.658       0.499
# Gender             -0.1815      2.467     -0.074      0.942      -5.090       4.727
# ==============================================================================
# Omnibus:                        0.083   Durbin-Watson:                   1.506
# Prob(Omnibus):                  0.959   Jarque-Bera (JB):                0.035
# Skew:                           0.042   Prob(JB):                        0.983
# Kurtosis:                       2.948   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: LYMPH_baseline
#                       sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           133.784457   1.0  1.477702  0.227666               NaN
# Age                 0.015898   1.0  0.000176  0.989460               NaN
# Education_years    73.226177   1.0  0.808812  0.371138               NaN
# Gender              1.075219   1.0  0.011876  0.913489               NaN
# Residual         7333.373180  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         LYMPH_baseline   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.014
# Method:                 Least Squares   F-statistic:                    0.6980
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.596
# Time:                        18:59:50   Log-Likelihood:                -313.20
# No. Observations:                  86   AIC:                             636.4
# Df Residuals:                      81   BIC:                             648.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          32.0137      5.045      6.346      0.000      21.976      42.051
# Cluster            -1.5199      1.250     -1.216      0.228      -4.008       0.968
# Age                -0.0016      0.119     -0.013      0.989      -0.239       0.236
# Education_years     0.2432      0.270      0.899      0.371      -0.295       0.781
# Gender              0.2499      2.293      0.109      0.913      -4.313       4.813
# ==============================================================================
# Omnibus:                        1.496   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.473   Jarque-Bera (JB):                0.939
# Skew:                          -0.010   Prob(JB):                        0.625
# Kurtosis:                       3.512   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: LYMPH_followup
#                       sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           181.938445   1.0  1.906351  0.171167               NaN
# Age                 0.295167   1.0  0.003093  0.955787               NaN
# Education_years    36.585227   1.0  0.383340  0.537559               NaN
# Gender             11.695000   1.0  0.122540  0.727204               NaN
# Residual         7730.482658  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         LYMPH_baseline   R-squared:                       0.033
# Model:                            OLS   Adj. R-squared:                 -0.015
# Method:                 Least Squares   F-statistic:                    0.6856
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.604
# Time:                        18:59:50   Log-Likelihood:                -315.47
# No. Observations:                  86   AIC:                             640.9
# Df Residuals:                      81   BIC:                             653.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          30.7271      5.180      5.932      0.000      20.421      41.033
# Cluster             1.7725      1.284      1.381      0.171      -0.782       4.327
# Age                -0.0068      0.123     -0.056      0.956      -0.251       0.237
# Education_years    -0.1719      0.278     -0.619      0.538      -0.724       0.381
# Gender              0.8243      2.355      0.350      0.727      -3.861       5.509
# ==============================================================================
# Omnibus:                        0.187   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.911   Jarque-Bera (JB):                0.235
# Skew:                           0.107   Prob(JB):                        0.889
# Kurtosis:                       2.858   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: MONO_baseline
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            0.254887   1.0  0.084696  0.771776               NaN
# Age                1.790964   1.0  0.595115  0.442692               NaN
# Education_years    0.201936   1.0  0.067101  0.796263               NaN
# Gender             4.124960   1.0  1.370674  0.245129               NaN
# Residual         243.764569  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          MONO_baseline   R-squared:                       0.020
# Model:                            OLS   Adj. R-squared:                 -0.028
# Method:                 Least Squares   F-statistic:                    0.4212
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.793
# Time:                        18:59:50   Log-Likelihood:                -166.83
# No. Observations:                  86   AIC:                             343.7
# Df Residuals:                      81   BIC:                             355.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.2435      0.920      6.788      0.000       4.413       8.074
# Cluster             0.0663      0.228      0.291      0.772      -0.387       0.520
# Age                 0.0168      0.022      0.771      0.443      -0.027       0.060
# Education_years     0.0128      0.049      0.259      0.796      -0.085       0.111
# Gender             -0.4895      0.418     -1.171      0.245      -1.321       0.342
# ==============================================================================
# Omnibus:                       19.736   Durbin-Watson:                   2.357
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               24.248
# Skew:                           1.198   Prob(JB):                     5.43e-06
# Kurtosis:                       4.014   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: MONO_followup
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           12.211183   1.0  4.347722  0.040208               NaN
# Age                1.052634   1.0  0.374784  0.542123               NaN
# Education_years    0.059173   1.0  0.021068  0.884954               NaN
# Gender             3.310830   1.0  1.178802  0.280821               NaN
# Residual         227.499773  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          MONO_baseline   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.017
# Method:                 Least Squares   F-statistic:                     1.374
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.250
# Time:                        18:59:50   Log-Likelihood:                -163.86
# No. Observations:                  86   AIC:                             337.7
# Df Residuals:                      81   BIC:                             350.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           5.9660      0.889      6.714      0.000       4.198       7.734
# Cluster             0.4592      0.220      2.085      0.040       0.021       0.897
# Age                 0.0129      0.021      0.612      0.542      -0.029       0.055
# Education_years     0.0069      0.048      0.145      0.885      -0.088       0.102
# Gender             -0.4386      0.404     -1.086      0.281      -1.242       0.365
# ==============================================================================
# Omnibus:                       14.919   Durbin-Watson:                   1.727
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               18.102
# Skew:                           0.858   Prob(JB):                     0.000117
# Kurtosis:                       4.452   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: PIL_baseline
#                         sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            2204.315714   1.0  0.673436  0.414265               NaN
# Age                 303.832693   1.0  0.092823  0.761400               NaN
# Education_years     793.296392   1.0  0.242358  0.623840               NaN
# Gender              899.826874   1.0  0.274904  0.601493               NaN
# Residual         265132.165504  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PIL_baseline   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.036
# Method:                 Least Squares   F-statistic:                    0.2583
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.904
# Time:                        18:59:50   Log-Likelihood:                -467.48
# No. Observations:                  86   AIC:                             945.0
# Df Residuals:                      81   BIC:                             957.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         199.6656     30.334      6.582      0.000     139.310     260.021
# Cluster            -6.1696      7.518     -0.821      0.414     -21.128       8.789
# Age                 0.2186      0.717      0.305      0.761      -1.209       1.646
# Education_years    -0.8006      1.626     -0.492      0.624      -4.036       2.435
# Gender              7.2302     13.790      0.524      0.601     -20.207      34.667
# ==============================================================================
# Omnibus:                       10.085   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.006   Jarque-Bera (JB):               10.243
# Skew:                           0.827   Prob(JB):                      0.00597
# Kurtosis:                       3.349   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: PIL_followup
#                         sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           11235.151287   1.0  2.831988  0.096255               NaN
# Age                8262.066054   1.0  2.082578  0.152845               NaN
# Education_years   18048.543262   1.0  4.549406  0.035957               NaN
# Gender             1322.329043   1.0  0.333313  0.565316               NaN
# Residual         321345.681565  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PIL_baseline   R-squared:                       0.124
# Model:                            OLS   Adj. R-squared:                  0.080
# Method:                 Least Squares   F-statistic:                     2.860
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):             0.0285
# Time:                        18:59:50   Log-Likelihood:                -475.74
# No. Observations:                  86   AIC:                             961.5
# Df Residuals:                      81   BIC:                             973.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         191.5433     33.395      5.736      0.000     125.097     257.989
# Cluster            13.9287      8.277      1.683      0.096      -2.540      30.397
# Age                 1.1399      0.790      1.443      0.153      -0.432       2.711
# Education_years    -3.8187      1.790     -2.133      0.036      -7.381      -0.256
# Gender              8.7647     15.181      0.577      0.565     -21.441      38.971
# ==============================================================================
# Omnibus:                        9.028   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.011   Jarque-Bera (JB):                9.074
# Skew:                           0.637   Prob(JB):                       0.0107
# Kurtosis:                       3.955   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: CRP_baseline
#                       sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster             1.947009   1.0  0.099826  0.752851               NaN
# Age                 1.961799   1.0  0.100584  0.751946               NaN
# Education_years    47.115980   1.0  2.415704  0.124023               NaN
# Gender              3.747524   1.0  0.192141  0.662308               NaN
# Residual         1579.826910  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           CRP_baseline   R-squared:                       0.030
# Model:                            OLS   Adj. R-squared:                 -0.017
# Method:                 Least Squares   F-statistic:                    0.6368
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.638
# Time:                        18:59:50   Log-Likelihood:                -247.19
# No. Observations:                  86   AIC:                             504.4
# Df Residuals:                      81   BIC:                             516.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           8.5161      2.342      3.637      0.000       3.857      13.175
# Cluster            -0.1834      0.580     -0.316      0.753      -1.338       0.971
# Age                -0.0176      0.055     -0.317      0.752      -0.128       0.093
# Education_years    -0.1951      0.126     -1.554      0.124      -0.445       0.055
# Gender              0.4666      1.064      0.438      0.662      -1.651       2.585
# ==============================================================================
# Omnibus:                       67.741   Durbin-Watson:                   2.346
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              351.884
# Skew:                           2.563   Prob(JB):                     3.88e-77
# Kurtosis:                      11.481   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: CRP_followup
#                       sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster             2.284772   1.0  0.094831  0.758913               NaN
# Age                38.753651   1.0  1.608501  0.208336               NaN
# Education_years     0.357518   1.0  0.014839  0.903347               NaN
# Gender             48.949848   1.0  2.031702  0.157890               NaN
# Residual         1951.535088  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           CRP_baseline   R-squared:                       0.060
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.301
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.277
# Time:                        18:59:50   Log-Likelihood:                -256.28
# No. Observations:                  86   AIC:                             522.6
# Df Residuals:                      81   BIC:                             534.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          12.0015      2.602      4.612      0.000       6.823      17.180
# Cluster             0.1986      0.645      0.308      0.759      -1.085       1.482
# Age                -0.0781      0.062     -1.268      0.208      -0.201       0.044
# Education_years    -0.0170      0.140     -0.122      0.903      -0.295       0.261
# Gender             -1.6863      1.183     -1.425      0.158      -4.040       0.668
# ==============================================================================
# Omnibus:                       68.584   Durbin-Watson:                   2.023
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              403.965
# Skew:                           2.525   Prob(JB):                     1.91e-88
# Kurtosis:                      12.340   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: NLR_baseline
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            2.517455   1.0  1.162025  0.284246               NaN
# Age                0.196154   1.0  0.090542  0.764260               NaN
# Education_years    0.137126   1.0  0.063295  0.801998               NaN
# Gender             0.169257   1.0  0.078127  0.780565               NaN
# Residual         175.481533  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           NLR_baseline   R-squared:                       0.017
# Model:                            OLS   Adj. R-squared:                 -0.031
# Method:                 Least Squares   F-statistic:                    0.3513
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.842
# Time:                        18:59:50   Log-Likelihood:                -152.70
# No. Observations:                  86   AIC:                             315.4
# Df Residuals:                      81   BIC:                             327.7
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.7871      0.780      2.290      0.025       0.234       3.340
# Cluster             0.2085      0.193      1.078      0.284      -0.176       0.593
# Age                -0.0056      0.018     -0.301      0.764      -0.042       0.031
# Education_years     0.0105      0.042      0.252      0.802      -0.073       0.094
# Gender              0.0992      0.355      0.280      0.781      -0.607       0.805
# ==============================================================================
# Omnibus:                      114.619   Durbin-Watson:                   2.172
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2684.344
# Skew:                           4.339   Prob(JB):                         0.00
# Kurtosis:                      28.958   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: NLR_followup
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           1.257749   1.0  1.079981  0.301794               NaN
# Age               0.426354   1.0  0.366094  0.546833               NaN
# Education_years   1.012391   1.0  0.869302  0.353919               NaN
# Gender            0.220897   1.0  0.189675  0.664345               NaN
# Residual         94.332807  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           NLR_baseline   R-squared:                       0.035
# Model:                            OLS   Adj. R-squared:                 -0.012
# Method:                 Least Squares   F-statistic:                    0.7434
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.565
# Time:                        18:59:50   Log-Likelihood:                -126.01
# No. Observations:                  86   AIC:                             262.0
# Df Residuals:                      81   BIC:                             274.3
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           2.4559      0.572      4.292      0.000       1.317       3.594
# Cluster            -0.1474      0.142     -1.039      0.302      -0.430       0.135
# Age                -0.0082      0.014     -0.605      0.547      -0.035       0.019
# Education_years     0.0286      0.031      0.932      0.354      -0.032       0.090
# Gender             -0.1133      0.260     -0.436      0.664      -0.631       0.404
# ==============================================================================
# Omnibus:                       36.362   Durbin-Watson:                   1.816
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               76.446
# Skew:                           1.580   Prob(JB):                     2.51e-17
# Kurtosis:                       6.369   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: PLR_baseline
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            3.803943   1.0  0.493472  0.484397               NaN
# Age                0.106288   1.0  0.013788  0.906815               NaN
# Education_years    0.633940   1.0  0.082239  0.775018               NaN
# Gender             0.800531   1.0  0.103850  0.748088               NaN
# Residual         624.391108  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PLR_baseline   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.039
# Method:                 Least Squares   F-statistic:                    0.2046
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.935
# Time:                        18:59:50   Log-Likelihood:                -207.27
# No. Observations:                  86   AIC:                             424.5
# Df Residuals:                      81   BIC:                             436.8
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.1738      1.472      4.194      0.000       3.245       9.103
# Cluster             0.2563      0.365      0.702      0.484      -0.470       0.982
# Age                 0.0041      0.035      0.117      0.907      -0.065       0.073
# Education_years    -0.0226      0.079     -0.287      0.775      -0.180       0.134
# Gender              0.2157      0.669      0.322      0.748      -1.116       1.547
# ==============================================================================
# Omnibus:                       45.136   Durbin-Watson:                   1.852
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              144.767
# Skew:                           1.733   Prob(JB):                     3.67e-32
# Kurtosis:                       8.328   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: PLR_followup
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            1.292968   1.0  0.113707  0.736835               NaN
# Age               11.388103   1.0  1.001500  0.319928               NaN
# Education_years    0.020668   1.0  0.001818  0.966099               NaN
# Gender             0.983265   1.0  0.086471  0.769465               NaN
# Residual         921.054976  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           PLR_baseline   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                    0.2742
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.894
# Time:                        18:59:50   Log-Likelihood:                -223.99
# No. Observations:                  86   AIC:                             458.0
# Df Residuals:                      81   BIC:                             470.2
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.4653      1.788      3.616      0.001       2.908      10.023
# Cluster            -0.1494      0.443     -0.337      0.737      -1.031       0.732
# Age                 0.0423      0.042      1.001      0.320      -0.042       0.126
# Education_years     0.0041      0.096      0.043      0.966      -0.187       0.195
# Gender             -0.2390      0.813     -0.294      0.769      -1.856       1.378
# ==============================================================================
# Omnibus:                       29.058   Durbin-Watson:                   1.953
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               48.141
# Skew:                           1.388   Prob(JB):                     3.52e-11
# Kurtosis:                       5.393   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: MLR_baseline
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.013355   1.0  0.525054  0.470782               NaN
# Age              0.000235   1.0  0.009224  0.923725               NaN
# Education_years  0.002101   1.0  0.082602  0.774535               NaN
# Gender           0.000181   1.0  0.007104  0.933038               NaN
# Residual         2.060317  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           MLR_baseline   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.042
# Method:                 Least Squares   F-statistic:                    0.1461
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.964
# Time:                        18:59:50   Log-Likelihood:                 38.425
# No. Observations:                  86   AIC:                            -66.85
# Df Residuals:                      81   BIC:                            -54.58
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1909      0.085      2.258      0.027       0.023       0.359
# Cluster             0.0152      0.021      0.725      0.471      -0.027       0.057
# Age                 0.0002      0.002      0.096      0.924      -0.004       0.004
# Education_years     0.0013      0.005      0.287      0.775      -0.008       0.010
# Gender             -0.0032      0.038     -0.084      0.933      -0.080       0.073
# ==============================================================================
# Omnibus:                       96.894   Durbin-Watson:                   2.284
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1247.396
# Skew:                           3.611   Prob(JB):                    1.35e-271
# Kurtosis:                      20.203   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: MLR_followup
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.002866   1.0  0.197622  0.657833               NaN
# Age              0.008565   1.0  0.590701  0.444383               NaN
# Education_years  0.014187   1.0  0.978393  0.325541               NaN
# Gender           0.009801   1.0  0.675920  0.413409               NaN
# Residual         1.174541  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           MLR_baseline   R-squared:                       0.025
# Model:                            OLS   Adj. R-squared:                 -0.023
# Method:                 Least Squares   F-statistic:                    0.5239
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.718
# Time:                        18:59:50   Log-Likelihood:                 62.590
# No. Observations:                  86   AIC:                            -115.2
# Df Residuals:                      81   BIC:                            -102.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.1890      0.064      2.960      0.004       0.062       0.316
# Cluster            -0.0070      0.016     -0.445      0.658      -0.039       0.024
# Age                 0.0012      0.002      0.769      0.444      -0.002       0.004
# Education_years     0.0034      0.003      0.989      0.326      -0.003       0.010
# Gender             -0.0239      0.029     -0.822      0.413      -0.082       0.034
# ==============================================================================
# Omnibus:                       45.866   Durbin-Watson:                   2.040
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              111.923
# Skew:                           1.963   Prob(JB):                     4.97e-25
# Kurtosis:                       6.977   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: SIII_baseline
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          4.945784e+04   1.0  0.933676  0.336786               NaN
# Age              4.690606e+00   1.0  0.000089  0.992515               NaN
# Education_years  6.049526e+02   1.0  0.011420  0.915159               NaN
# Gender           2.054615e+03   1.0  0.038787  0.844364               NaN
# Residual         4.290657e+06  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          SIII_baseline   R-squared:                       0.013
# Model:                            OLS   Adj. R-squared:                 -0.035
# Method:                 Least Squares   F-statistic:                    0.2720
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.895
# Time:                        18:59:50   Log-Likelihood:                -587.19
# No. Observations:                  86   AIC:                             1184.
# Df Residuals:                      81   BIC:                             1197.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         363.3876    122.028      2.978      0.004     120.589     606.186
# Cluster            29.2240     30.244      0.966      0.337     -30.952      89.400
# Age                -0.0272      2.886     -0.009      0.993      -5.770       5.715
# Education_years    -0.6991      6.542     -0.107      0.915     -13.716      12.318
# Gender             10.9253     55.474      0.197      0.844     -99.450     121.301
# ==============================================================================
# Omnibus:                       67.197   Durbin-Watson:                   1.945
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              454.400
# Skew:                           2.371   Prob(JB):                     2.13e-99
# Kurtosis:                      13.214   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: SIII_followup
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          3.805032e+03   1.0  0.073823  0.786541               NaN
# Age              1.233890e+03   1.0  0.023939  0.877425               NaN
# Education_years  7.488481e+01   1.0  0.001453  0.969689               NaN
# Gender           2.879056e+04   1.0  0.558578  0.456998               NaN
# Residual         4.174948e+06  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          SIII_baseline   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.041
# Method:                 Least Squares   F-statistic:                    0.1703
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.953
# Time:                        18:59:50   Log-Likelihood:                -586.01
# No. Observations:                  86   AIC:                             1182.
# Df Residuals:                      81   BIC:                             1194.
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         491.9724    120.372      4.087      0.000     252.470     731.474
# Cluster             8.1059     29.834      0.272      0.787     -51.253      67.465
# Age                 0.4405      2.847      0.155      0.877      -5.224       6.105
# Education_years    -0.2460      6.453     -0.038      0.970     -13.086      12.594
# Gender            -40.8971     54.721     -0.747      0.457    -149.774      67.980
# ==============================================================================
# Omnibus:                       18.753   Durbin-Watson:                   1.797
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               22.888
# Skew:                           1.105   Prob(JB):                     1.07e-05
# Kurtosis:                       4.227   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: ASTALT_baseline
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           0.419400   1.0  1.872342  0.174991               NaN
# Age               0.065377   1.0  0.291866  0.590510               NaN
# Education_years   0.047307   1.0  0.211194  0.647064               NaN
# Gender            0.194581   1.0  0.868675  0.354092               NaN
# Residual         18.143787  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        ASTALT_baseline   R-squared:                       0.040
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.8346
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.507
# Time:                        18:59:50   Log-Likelihood:                -55.120
# No. Observations:                  86   AIC:                             120.2
# Df Residuals:                      81   BIC:                             132.5
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.9955      0.251      3.967      0.000       0.496       1.495
# Cluster             0.0851      0.062      1.368      0.175      -0.039       0.209
# Age                -0.0032      0.006     -0.540      0.591      -0.015       0.009
# Education_years    -0.0062      0.013     -0.460      0.647      -0.033       0.021
# Gender              0.1063      0.114      0.932      0.354      -0.121       0.333
# ==============================================================================
# Omnibus:                        5.294   Durbin-Watson:                   2.377
# Prob(Omnibus):                  0.071   Jarque-Bera (JB):                6.478
# Skew:                           0.227   Prob(JB):                       0.0392
# Kurtosis:                       4.265   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: ASTALT_followup
#                     sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           0.020929   1.0  0.104349  0.747505               NaN
# Age               0.158161   1.0  0.788574  0.377161               NaN
# Education_years   0.401392   1.0  2.001298  0.160997               NaN
# Gender            0.011892   1.0  0.059293  0.808232               NaN
# Residual         16.245826  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:        ASTALT_baseline   R-squared:                       0.036
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.7612
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.554
# Time:                        18:59:50   Log-Likelihood:                -50.369
# No. Observations:                  86   AIC:                             110.7
# Df Residuals:                      81   BIC:                             123.0
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           1.0072      0.237      4.242      0.000       0.535       1.480
# Cluster            -0.0190      0.059     -0.323      0.748      -0.136       0.098
# Age                 0.0050      0.006      0.888      0.377      -0.006       0.016
# Education_years    -0.0180      0.013     -1.415      0.161      -0.043       0.007
# Gender             -0.0263      0.108     -0.244      0.808      -0.241       0.188
# ==============================================================================
# Omnibus:                        7.416   Durbin-Watson:                   2.015
# Prob(Omnibus):                  0.025   Jarque-Bera (JB):               13.551
# Skew:                          -0.132   Prob(JB):                      0.00114
# Kurtosis:                       4.927   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: LDH_baseline
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            536.969950   1.0  1.202369  0.276098               NaN
# Age                111.455930   1.0  0.249569  0.618733               NaN
# Education_years     67.254053   1.0  0.150594  0.698987               NaN
# Gender             846.872875   1.0  1.896296  0.172287               NaN
# Residual         36174.044786  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           LDH_baseline   R-squared:                       0.052
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.120
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.353
# Time:                        18:59:50   Log-Likelihood:                -381.82
# No. Observations:                  86   AIC:                             773.6
# Df Residuals:                      81   BIC:                             785.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         138.0741     11.205     12.323      0.000     115.780     160.368
# Cluster             3.0451      2.777      1.097      0.276      -2.480       8.570
# Age                 0.1324      0.265      0.500      0.619      -0.395       0.660
# Education_years    -0.2331      0.601     -0.388      0.699      -1.428       0.962
# Gender              7.0142      5.094      1.377      0.172      -3.120      17.149
# ==============================================================================
# Omnibus:                        1.030   Durbin-Watson:                   1.964
# Prob(Omnibus):                  0.598   Jarque-Bera (JB):                0.865
# Skew:                           0.245   Prob(JB):                        0.649
# Kurtosis:                       2.957   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: LDH_followup
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster           3445.405793   1.0  5.607161  0.020271               NaN
# Age                 26.910520   1.0  0.043795  0.834761               NaN
# Education_years     18.923020   1.0  0.030796  0.861134               NaN
# Gender             129.315490   1.0  0.210452  0.647642               NaN
# Residual         49771.689756  81.0       NaN       NaN               NaN
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           LDH_baseline   R-squared:                       0.075
# Model:                            OLS   Adj. R-squared:                  0.029
# Method:                 Least Squares   F-statistic:                     1.631
# Date:                Fri, 21 Mar 2025   Prob (F-statistic):              0.174
# Time:                        18:59:50   Log-Likelihood:                -395.55
# No. Observations:                  86   AIC:                             801.1
# Df Residuals:                      81   BIC:                             813.4
# Df Model:                           4
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         134.4022     13.143     10.226      0.000     108.252     160.552
# Cluster             7.7133      3.257      2.368      0.020       1.232      14.195
# Age                 0.0651      0.311      0.209      0.835      -0.553       0.684
# Education_years     0.1236      0.705      0.175      0.861      -1.278       1.526
# Gender              2.7409      5.975      0.459      0.648      -9.147      14.629
# ==============================================================================
# Omnibus:                        1.688   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.430   Jarque-Bera (JB):                1.078
# Skew:                           0.173   Prob(JB):                        0.583
# Kurtosis:                       3.425   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats.multitest import multipletests
import warnings

warnings.filterwarnings('ignore')
# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet2')

# 删除 'Cluster' 列中等于 3 的行
data_cleaned = data[data['Cluster'] != 3]

# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ( "WBC_baseline", "WBC_followup"),
    ("NEUT_baseline", "NEUT_followup"),
    ("LYMPH_baseline", "LYMPH_followup"),
    ("MONO_baseline", "MONO_followup"),
    ("PIL_baseline", "PIL_followup"),
    ("CRP_baseline", "CRP_followup"),
    ("NLR_baseline", "NLR_followup"),
    ("PLR_baseline", "PLR_followup"),
    ("MLR_baseline", "MLR_followup"),
    ("SIII_baseline", "SIII_followup"),
    ("ASTALT_baseline", "ASTALT_followup"),
    ("LDH_baseline", "LDH_followup"),
]

# 创建字典以存储结果
results = {}

# 定义函数进行配对t检验
def perform_paired_ttest(group, baseline_var, followup_var):
    baseline_scores = data[data['Cluster'] == group][baseline_var]
    followup_scores = data[data['Cluster'] == group][followup_var]
    
    # 进行配对t检验
    t_stat, p_value = stats.ttest_rel(baseline_scores, followup_scores)
    
    return p_value

# 对每个变量在两个亚组进行分析并存储结果
for baseline_var, followup_var in variables:
    p_values_group1 = perform_paired_ttest(0, baseline_var, followup_var)
    p_values_group2 = perform_paired_ttest(1, baseline_var, followup_var)
    
    # 将结果存储在字典中
    results[(baseline_var, 'Group1')] = p_values_group1
    results[(baseline_var, 'Group2')] = p_values_group2

# 将p值进行FDR BH校正
p_values = list(results.values())
p_values_corrected = multipletests(p_values, method='fdr_bh')[1]

# 更新结果字典
corrected_results = {}
for i, key in enumerate(results.keys()):
    corrected_results[key] = p_values_corrected[i]

# 输出结果
for var in variables:
    print(f"Variable: {var[0]}")
    print(f"Group 1 (Subtype I) p-value (corrected): {corrected_results[(var[0], 'Group1')]:.4f}")
    print(f"Group 2 (Subtype II) p-value (corrected): {corrected_results[(var[0], 'Group2')]:.4f}")
    print("---")
# Out:
# Variable: WBC_baseline
# Group 1 (Subtype I) p-value (corrected): 0.1078
# Group 2 (Subtype II) p-value (corrected): 0.0368
# ---
# Variable: NEUT_baseline
# Group 1 (Subtype I) p-value (corrected): 0.4680
# Group 2 (Subtype II) p-value (corrected): 0.0631
# ---
# Variable: LYMPH_baseline
# Group 1 (Subtype I) p-value (corrected): 0.0241
# Group 2 (Subtype II) p-value (corrected): 0.9640
# ---
# Variable: MONO_baseline
# Group 1 (Subtype I) p-value (corrected): 0.4642
# Group 2 (Subtype II) p-value (corrected): 0.6936
# ---
# Variable: PIL_baseline
# Group 1 (Subtype I) p-value (corrected): 0.0368
# Group 2 (Subtype II) p-value (corrected): 0.0015
# ---
# Variable: CRP_baseline
# Group 1 (Subtype I) p-value (corrected): 0.6936
# Group 2 (Subtype II) p-value (corrected): 0.6936
# ---
# Variable: NLR_baseline
# Group 1 (Subtype I) p-value (corrected): 0.0455
# Group 2 (Subtype II) p-value (corrected): 0.8443
# ---
# Variable: PLR_baseline
# Group 1 (Subtype I) p-value (corrected): 0.3165
# Group 2 (Subtype II) p-value (corrected): 0.1446
# ---
# Variable: MLR_baseline
# Group 1 (Subtype I) p-value (corrected): 0.1055
# Group 2 (Subtype II) p-value (corrected): 0.4680
# ---
# Variable: SIII_baseline
# Group 1 (Subtype I) p-value (corrected): 0.3757
# Group 2 (Subtype II) p-value (corrected): 0.1582
# ---
# Variable: ASTALT_baseline
# Group 1 (Subtype I) p-value (corrected): 0.9575
# Group 2 (Subtype II) p-value (corrected): 0.2325
# ---
# Variable: LDH_baseline
# Group 1 (Subtype I) p-value (corrected): 0.0270
# Group 2 (Subtype II) p-value (corrected): 0.1784
# ---

# %%
# 计算两个组中各变量的前侧（baseline）和后侧（followup）的均值和标准差

for baseline_var, followup_var in variables:
    print(f"Variable: {baseline_var}")
    for group in [0, 1]:
        # 根据分组赋予标签
        group_label = "Group 1 (Subtype I)" if group == 0 else "Group 2 (Subtype II)"
        
        # 从清洗后的数据中获取各组对应变量的值
        baseline_scores = data_cleaned[data_cleaned['Cluster'] == group][baseline_var]
        followup_scores = data_cleaned[data_cleaned['Cluster'] == group][followup_var]
        
        # 计算均值和标准差
        baseline_mean = baseline_scores.mean()
        baseline_std = baseline_scores.std()
        followup_mean = followup_scores.mean()
        followup_std = followup_scores.std()
        
        # 打印结果
        print(f"{group_label}:")
        print(f"  Baseline - Mean: {baseline_mean:.4f}, Std: {baseline_std:.4f}")
        print(f"  Followup - Mean: {followup_mean:.4f}, Std: {followup_std:.4f}")
    print("---")
# Out:
# Variable: WBC_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 5.9577, Std: 1.4991
#   Followup - Mean: 6.5384, Std: 1.9997
# Group 2 (Subtype II):
#   Baseline - Mean: 5.6632, Std: 1.2994
#   Followup - Mean: 6.3137, Std: 1.4857
# ---
# Variable: NEUT_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 55.7835, Std: 8.5599
#   Followup - Mean: 57.7038, Std: 10.2591
# Group 2 (Subtype II):
#   Baseline - Mean: 57.7205, Std: 10.0159
#   Followup - Mean: 61.7668, Std: 9.9325
# ---
# Variable: LYMPH_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 35.4436, Std: 8.2442
#   Followup - Mean: 28.2269, Std: 9.9527
# Group 2 (Subtype II):
#   Baseline - Mean: 32.9393, Std: 10.1824
#   Followup - Mean: 33.0222, Std: 9.4640
# ---
# Variable: MONO_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 6.1786, Std: 1.6493
#   Followup - Mean: 5.9144, Std: 1.2050
# Group 2 (Subtype II):
#   Baseline - Mean: 6.4639, Std: 1.8353
#   Followup - Mean: 6.3113, Std: 1.7250
# ---
# Variable: PIL_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 206.8563, Std: 61.6128
#   Followup - Mean: 169.8710, Std: 43.7544
# Group 2 (Subtype II):
#   Baseline - Mean: 203.5188, Std: 54.5864
#   Followup - Mean: 245.4894, Std: 61.9572
# ---
# Variable: CRP_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 6.1588, Std: 4.7677
#   Followup - Mean: 6.7183, Std: 3.5013
# Group 2 (Subtype II):
#   Baseline - Mean: 6.5103, Std: 4.4421
#   Followup - Mean: 7.1758, Std: 5.9716
# ---
# Variable: NLR_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 1.7304, Std: 0.7389
#   Followup - Mean: 2.4254, Std: 1.3015
# Group 2 (Subtype II):
#   Baseline - Mean: 2.1710, Std: 1.7942
#   Followup - Mean: 2.0940, Std: 0.9197
# ---
# Variable: PLR_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 6.1741, Std: 2.2991
#   Followup - Mean: 7.2179, Std: 4.3924
# Group 2 (Subtype II):
#   Baseline - Mean: 6.8027, Std: 2.9243
#   Followup - Mean: 7.8891, Std: 2.5006
# ---
# Variable: MLR_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 0.1892, Std: 0.0963
#   Followup - Mean: 0.2487, Std: 0.1357
# Group 2 (Subtype II):
#   Baseline - Mean: 0.2403, Std: 0.1930
#   Followup - Mean: 0.2105, Std: 0.1075
# ---
# Variable: SIII_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 357.5618, Std: 170.1282
#   Followup - Mean: 410.9486, Std: 247.4966
# Group 2 (Subtype II):
#   Baseline - Mean: 411.0236, Std: 250.3919
#   Followup - Mean: 493.9219, Std: 203.5138
# ---
# Variable: ASTALT_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 0.9044, Std: 0.4732
#   Followup - Mean: 0.9148, Std: 0.3652
# Group 2 (Subtype II):
#   Baseline - Mean: 1.1072, Std: 0.4769
#   Followup - Mean: 0.9574, Std: 0.4643
# ---
# Variable: LDH_baseline
# Group 1 (Subtype I):
#   Baseline - Mean: 148.3665, Std: 20.8565
#   Followup - Mean: 129.4010, Std: 21.1842
# Group 2 (Subtype II):
#   Baseline - Mean: 153.9177, Std: 21.4038
#   Followup - Mean: 161.6007, Std: 20.3105
# ---

# %%
print('全部完成！')
# Out:
# 全部完成！
