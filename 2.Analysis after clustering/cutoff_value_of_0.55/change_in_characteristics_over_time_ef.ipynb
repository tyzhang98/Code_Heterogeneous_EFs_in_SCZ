# %% [markdown]
# ## 最为整体

# %% [markdown]
# ## 区分亚组

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import mixedlm
from statsmodels.stats.multitest import multipletests
from statsmodels.stats.multicomp import MultiComparison
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import warnings

warnings.filterwarnings('ignore')

# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet3')

# 删除 'Group' 列中等于 3 的行
data = data[data['Cluster'] != 3]

# 将列名中的空格替换为下划线，去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ("reaction_times_in_incongruent_stimuli_at_baseline", "reaction_times_in_incongruent_stimuli_at_follow-up"),
    ("stroop_interference_effect_at_baseline", "stroop_interference_effect_at_follow-up"),
    ("accuracy_in_Nogo_trials_at_baseline", "accuracy_in_Nogo_trials_at_follow-up"),
    ("Switching_cost_at_baseline", "Switching_cost_at_follow-up"),
    ("accuracy_in_1750_ms_at_baseline", "accuracy_in_1750_ms_at_follow-up"),
    ("accuracy_in_750_ms_at_baseline", "accuracy_in_750_ms_at_follow-up"),
    ("span_in_digit_span_backward_task_at_baseline", "span_in_digit_span_backward_task_at_follow-up")
]

# 添加主题列
data['Subject'] = data.index
data = data.reset_index(drop=True)

# 确保所有列名一致
required_columns = [
    'Cluster', 'Subject', 'Age', 
    'Education_years', 'Gender'
]

missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"The following required columns are missing from the data: {missing_columns}")

# 创建字典以存储结果
results = {}

# 对每个变量进行线性混合效应模型分析
def perform_lmm_analysis(baseline_var, followup_var):
    # 确保变量名一致
    baseline_var = baseline_var.replace(' ', '_')
    followup_var = followup_var.replace(' ', '_')

    # 数据重塑为长格式
    df_long = pd.melt(data, id_vars=required_columns, 
                      value_vars=[baseline_var, followup_var], 
                      var_name='Time', value_name='Score')
    
    df_long['Time'] = df_long['Time'].map({baseline_var: 0, followup_var: 1})
    df_long['Cluster'] = df_long['Cluster'].astype('category')
    
    # 哑变量生成
    df_long = pd.get_dummies(df_long, columns=[
        'Gender'], drop_first=True)

    # 定义线性混合效应模型公式
    formula = ("Score ~ Time * Cluster + Age + "
               "Education_years + " +
               " + ".join(df_long.columns[df_long.columns.str.startswith(('Gender_'))]))
    
    md = mixedlm(formula, df_long, groups=df_long["Subject"], re_formula="~Time")
    mdf = md.fit()
    
    # 提取固定效应的p值
    p_values = mdf.pvalues.loc[['Time', 'Cluster[T.1]', 'Time:Cluster[T.1]']]

    # 多重比较校正
    _, p_values_corrected, _, _ = multipletests(p_values, method='fdr_bh', is_sorted=False)
    p_values_corrected_dict = dict(zip(p_values.index, p_values_corrected))

    # 存储结果
    return {
        'LMM_summary': mdf.summary(),
        'Time_pvalue': p_values.loc['Time'],
        'Cluster_pvalue': p_values.loc['Cluster[T.1]'],
        'Interaction_pvalue': p_values.loc['Time:Cluster[T.1]'],
        'Time_pvalue_corrected': p_values_corrected_dict['Time'],
        'Cluster_pvalue_corrected': p_values_corrected_dict['Cluster[T.1]'],
        'Interaction_pvalue_corrected': p_values_corrected_dict['Time:Cluster[T.1]'],
        'df_long': df_long  # Store the long format data for post-hoc analysis
    }

# 对每个变量进行分析并存储结果
for baseline_var, followup_var in variables:
    results[baseline_var] = perform_lmm_analysis(baseline_var, followup_var)

# 定义绘图函数
def plot_interaction(df_long, var_name):
    sns.set(style="whitegrid")
    plt.figure(figsize=(10, 6))
    
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette="muted")

    plt.title(f'Interaction Plot for {var_name}')
    plt.xlabel('Time')
    plt.ylabel('Score')
    plt.xticks([0, 1], ['Baseline', 'Follow-up'])
    plt.legend(title='Cluster', loc='upper left')
    plt.tight_layout()
    plt.show()

# 输出结果
for var, result in results.items():
    print(f"Variable: {var}")
    print(result['LMM_summary'])
    print(f"Time p-value (corrected): {result['Time_pvalue_corrected']:.3f}")
    print(f"Cluster p-value (corrected): {result['Cluster_pvalue_corrected']:.3f}")
    print(f"Interaction p-value (corrected): {result['Interaction_pvalue_corrected']:.3f}")

    # 进行事后比较
    if result['Interaction_pvalue_corrected'] < 0.05:  # Check for significance
        mc = MultiComparison(result['df_long']['Score'], 
                             result['df_long']['Time'].astype(str) + "_" + result['df_long']['Cluster'].astype(str))
        post_hoc_results = mc.tukeyhsd(alpha=0.05)

        # 修改Tukey HSD表的显示
        summary_df = pd.DataFrame(data=post_hoc_results.summary().data[1:], columns=post_hoc_results.summary().data[0])
        summary_df['group1'] = summary_df['group1'].replace({'0_0': 'baseline_Subtype I', '0_1': 'baseline_Subtype II', 
                                                             '1_0': 'followup_Subtype I', '1_1': 'followup_Subtype II'})
        summary_df['group2'] = summary_df['group2'].replace({'0_0': 'baseline_Subtype I', '0_1': 'baseline_Subtype II', 
                                                             '1_0': 'followup_Subtype I', '1_1': 'followup_Subtype II'})
        print(tabulate(summary_df, headers='keys', tablefmt='pretty'))

        # 输出均值和标准差
        means = result['df_long'].groupby(['Time', 'Cluster'])['Score'].agg(['mean', 'std']).reset_index()
        means['Cluster'] = means['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
        means['Time'] = means['Time'].map({0: 'baseline', 1: 'followup'})
        
        for idx, row in means.iterrows():
            print(f"Cluster: {row['Cluster']}, Time: {row['Time']}, Mean: {row['mean']:.2f}, Std: {row['std']:.2f}")
    print("---")
# Out:
# Variable: reaction_times_in_incongruent_stimuli_at_baseline
#               Mixed Linear Model Regression Results
# =================================================================
# Model:                MixedLM    Dependent Variable:    Score
# No. Observations:     156        Method:                REML
# No. Groups:           78         Scale:                 8853.2876
# Min. group size:      2          Log-Likelihood:        -959.4135
# Max. group size:      2          Converged:             Yes
# Mean group size:      2.0
# -----------------------------------------------------------------
#                     Coef.   Std.Err.   z    P>|z|  [0.025  0.975]
# -----------------------------------------------------------------
# Intercept           694.406   74.004  9.383 0.000 549.361 839.451
# Cluster[T.1]         28.341   37.366  0.758 0.448 -44.895 101.578
# Time                -26.768   26.612 -1.006 0.314 -78.927  25.391
# Time:Cluster[T.1]   -25.217   34.283 -0.736 0.462 -92.411  41.977
# Age                   1.028    1.673  0.615 0.539  -2.250   4.307
# Education_years      -1.206    4.067 -0.297 0.767  -9.177   6.765
# Gender_2             57.285   34.387  1.666 0.096 -10.112 124.682
# Group Var         14214.017
# Group x Time Cov  -4214.495
# Time Var           4248.267
# =================================================================
#
# Time p-value (corrected): 0.462
# Cluster p-value (corrected): 0.462
# Interaction p-value (corrected): 0.462
# ---
# Variable: stroop_interference_effect_at_baseline
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                MixedLM     Dependent Variable:     Score
# No. Observations:     156         Method:                 REML
# No. Groups:           78          Scale:                  4370.8685
# Min. group size:      2           Log-Likelihood:         -915.4507
# Max. group size:      2           Converged:              No
# Mean group size:      2.0
# -------------------------------------------------------------------
#                     Coef.    Std.Err.   z    P>|z|  [0.025   0.975]
# -------------------------------------------------------------------
# Intercept             16.866   45.921  0.367 0.713  -73.137 106.870
# Cluster[T.1]          48.545   32.109  1.512 0.131  -14.387 111.478
# Time                  20.128   25.848  0.779 0.436  -30.534  70.790
# Time:Cluster[T.1]    -59.015   33.299 -1.772 0.076 -124.280   6.250
# Age                   -0.803    0.946 -0.849 0.396   -2.656   1.050
# Education_years       -1.647    2.293 -0.718 0.473   -6.141   2.847
# Gender_2              14.382   18.904  0.761 0.447  -22.669  51.433
# Group Var          13955.421
# Group x Time Cov  -12323.026
# Time Var           11970.578
# ===================================================================
#
# Time p-value (corrected): 0.436
# Cluster p-value (corrected): 0.196
# Interaction p-value (corrected): 0.196
# ---
# Variable: accuracy_in_Nogo_trials_at_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM   Dependent Variable:   Score
# No. Observations:    156       Method:               REML
# No. Groups:          78        Scale:                0.0061
# Min. group size:     2         Log-Likelihood:       81.7582
# Max. group size:     2         Converged:            Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          0.742    0.075  9.881 0.000  0.595  0.889
# Cluster[T.1]       0.026    0.034  0.766 0.444 -0.041  0.094
# Time               0.008    0.022  0.365 0.715 -0.035  0.051
# Time:Cluster[T.1] -0.019    0.028 -0.665 0.506 -0.075  0.037
# Age                0.001    0.002  0.689 0.491 -0.002  0.005
# Education_years    0.003    0.004  0.786 0.432 -0.005  0.011
# Gender_2           0.018    0.035  0.516 0.606 -0.050  0.086
# Group Var          0.013
# Group x Time Cov  -0.000
# Time Var           0.003
# ============================================================
#
# Time p-value (corrected): 0.715
# Cluster p-value (corrected): 0.715
# Interaction p-value (corrected): 0.715
# ---
# Variable: Switching_cost_at_baseline
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:                 MixedLM    Dependent Variable:    Score
# No. Observations:      156        Method:                REML
# No. Groups:            78         Scale:                 57454.5425
# Min. group size:       2          Log-Likelihood:        -1074.2539
# Max. group size:       2          Converged:             Yes
# Mean group size:       2.0
# -------------------------------------------------------------------
#                     Coef.    Std.Err.   z    P>|z|  [0.025   0.975]
# -------------------------------------------------------------------
# Intercept            283.105  130.877  2.163 0.031   26.591 539.620
# Cluster[T.1]          52.765   75.613  0.698 0.485  -95.433 200.963
# Time                  88.312   71.685  1.232 0.218  -52.188 228.812
# Time:Cluster[T.1]   -169.957   92.348 -1.840 0.066 -350.955  11.042
# Age                   -4.325    2.874 -1.505 0.132   -9.958   1.308
# Education_years       14.203    6.976  2.036 0.042    0.530  27.875
# Gender_2             -64.819   57.584 -1.126 0.260 -177.682  48.043
# Group Var          40694.802
# Group x Time Cov  -34422.150
# Time Var           44392.138
# ===================================================================
#
# Time p-value (corrected): 0.327
# Cluster p-value (corrected): 0.485
# Interaction p-value (corrected): 0.197
# ---
# Variable: accuracy_in_1750_ms_at_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:              MixedLM   Dependent Variable:   Score
# No. Observations:   156       Method:               REML
# No. Groups:         78        Scale:                0.0308
# Min. group size:    2         Log-Likelihood:       -23.4589
# Max. group size:    2         Converged:            Yes
# Mean group size:    2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          0.525    0.131  4.004 0.000  0.268  0.782
# Cluster[T.1]      -0.114    0.063 -1.803 0.071 -0.237  0.010
# Time               0.011    0.052  0.206 0.837 -0.091  0.113
# Time:Cluster[T.1] -0.076    0.067 -1.131 0.258 -0.207  0.056
# Age                0.003    0.003  1.113 0.266 -0.003  0.009
# Education_years   -0.004    0.007 -0.506 0.613 -0.018  0.011
# Gender_2           0.064    0.060  1.064 0.287 -0.054  0.182
# Group Var          0.034
# Group x Time Cov  -0.006
# Time Var           0.023
# ============================================================
#
# Time p-value (corrected): 0.837
# Cluster p-value (corrected): 0.214
# Interaction p-value (corrected): 0.387
# ---
# Variable: accuracy_in_750_ms_at_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:              MixedLM   Dependent Variable:   Score
# No. Observations:   156       Method:               REML
# No. Groups:         78        Scale:                0.0339
# Min. group size:    2         Log-Likelihood:       -28.9948
# Max. group size:    2         Converged:            Yes
# Mean group size:    2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          0.611    0.141  4.324 0.000  0.334  0.887
# Cluster[T.1]      -0.101    0.071 -1.418 0.156 -0.241  0.039
# Time              -0.023    0.052 -0.435 0.663 -0.126  0.080
# Time:Cluster[T.1] -0.046    0.068 -0.686 0.493 -0.179  0.086
# Age               -0.003    0.003 -0.976 0.329 -0.009  0.003
# Education_years   -0.000    0.008 -0.032 0.975 -0.016  0.015
# Gender_2           0.137    0.064  2.141 0.032  0.012  0.263
# Group Var          0.050
# Group x Time Cov  -0.015
# Time Var           0.018
# ============================================================
#
# Time p-value (corrected): 0.663
# Cluster p-value (corrected): 0.468
# Interaction p-value (corrected): 0.663
# ---
# Variable: span_in_digit_span_backward_task_at_baseline
#            Mixed Linear Model Regression Results
# ============================================================
# Model:               MixedLM  Dependent Variable:  Score
# No. Observations:    156      Method:              REML
# No. Groups:          78       Scale:               0.8840
# Min. group size:     2        Log-Likelihood:      -280.6860
# Max. group size:     2        Converged:           Yes
# Mean group size:     2.0
# ------------------------------------------------------------
#                   Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# ------------------------------------------------------------
# Intercept          5.379    0.842  6.385 0.000  3.728  7.030
# Cluster[T.1]      -0.421    0.415 -1.014 0.310 -1.233  0.392
# Time               0.935    0.259  3.609 0.000  0.427  1.444
# Time:Cluster[T.1] -1.042    0.334 -3.120 0.002 -1.696 -0.387
# Age               -0.030    0.019 -1.552 0.121 -0.067  0.008
# Education_years    0.088    0.047  1.876 0.061 -0.004  0.181
# Gender_2          -0.044    0.382 -0.114 0.909 -0.793  0.705
# Group Var          1.946
# Group x Time Cov  -0.447
# Time Var           0.316
# ============================================================
#
# Time p-value (corrected): 0.001
# Cluster p-value (corrected): 0.310
# Interaction p-value (corrected): 0.003
# +---+---------------------+---------------------+----------+--------+---------+---------+--------+
# |   |       group1        |       group2        | meandiff | p-adj  |  lower  |  upper  | reject |
# +---+---------------------+---------------------+----------+--------+---------+---------+--------+
# | 0 | baseline_Subtype I  | baseline_Subtype II | -0.6321  | 0.3274 | -1.5982 |  0.334  | False  |
# | 1 | baseline_Subtype I  | followup_Subtype I  |  0.9355  | 0.1046 | -0.1251 | 1.9961  | False  |
# | 2 | baseline_Subtype I  | followup_Subtype II | -0.7385  | 0.1979 | -1.7046 | 0.2276  | False  |
# | 3 | baseline_Subtype II | followup_Subtype I  |  1.5676  | 0.0002 | 0.6015  | 2.5337  |  True  |
# | 4 | baseline_Subtype II | followup_Subtype II | -0.1064  | 0.9885 | -0.9677 |  0.755  | False  |
# | 5 | followup_Subtype I  | followup_Subtype II |  -1.674  | 0.0001 | -2.6401 | -0.7079 |  True  |
# +---+---------------------+---------------------+----------+--------+---------+---------+--------+
# Cluster: Subtype I, Time: baseline, Mean: 5.42, Std: 2.05
# Cluster: Subtype II, Time: baseline, Mean: 4.79, Std: 1.35
# Cluster: Subtype I, Time: followup, Mean: 6.35, Std: 1.62
# Cluster: Subtype II, Time: followup, Mean: 4.68, Std: 1.51
# ---

# %%
def plot_interaction(df_long, var_name):
    import seaborn as sns
    import matplotlib.pyplot as plt
    
    # 设置整体风格，确保图表清晰且专业，增强图表对比度
    sns.set(style="whitegrid", font_scale=1.2)
    plt.figure(figsize=(5, 4.6))  # 提高分辨率以满足高水平出版要求
    
    # 将群组标签映射到新的名称
    df_long['Cluster'] = df_long['Cluster'].map({0: 'Subtype I', 1: 'Subtype II'})
    

    palette = {"Subtype I": "#7b3294", "Subtype II": "#fdae61"}
    # 绘制带误差条的交互作用图，并调整透明度以突出关键趋势线
    sns.lineplot(x="Time", y="Score", hue="Cluster", 
                 data=df_long, markers=True, dashes=False, 
                 ci='sd', palette=palette, 
                 marker='s', linewidth=3.5, alpha=0.85, markersize=12)
    
    # 为每个亚组设置不同的颜色，并在X轴上错开显示
    offset = {'Subtype I': -0.1, 'Subtype II': 0.1}  # 设置X轴偏移量
    for cluster, color in zip(['Subtype I', 'Subtype II'], ["#7b3294", "#fdae61"]):
        grp = df_long[df_long['Cluster'] == cluster]
        for _, subject_grp in grp.groupby('Subject'):
            x_positions = subject_grp['Time'] + offset[cluster]  # 添加偏移量
            plt.plot(x_positions, subject_grp['Score'], marker='o', color=color, alpha=0.4, linewidth=1.0, markersize=4)

    # 图表标题和标签，使用更加清晰的字体大小和粗细
    plt.title(f'Span in digit span backward task \n(Adjusted for Sociodemographic Variables)', fontsize=14, fontweight='bold', pad=10)
    plt.xlabel('Time', fontsize=14, fontweight='bold')
    plt.ylabel('Score', fontsize=14, fontweight='bold')
    plt.xticks([0.1, 0.9], ['Baseline', 'Follow-up'], fontsize=12)
    
    # 调整图例的位置和标签，设置图例框架和位置
    plt.legend(loc='upper left', fontsize=11, frameon=False, ncol=2, bbox_to_anchor=(0.1,-0.2))
    
    # 设置网格线，提升图表的专业感，适度降低透明度
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()  # 自动调整布局，确保图表元素不重叠
    plt.savefig(f'image/{var_name}.jpg', dpi=1200, bbox_inches='tight')
    plt.show()

# 调用示例：绘制指定变量的交互作用图
var_name = 'span_in_digit_span_backward_task_at_baseline'
plot_interaction(results[var_name]['df_long'], var_name)

# %%
import pandas as pd
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from statsmodels.stats.multitest import multipletests
import seaborn as sns
import matplotlib.pyplot as plt
from tabulate import tabulate
import warnings

warnings.filterwarnings('ignore')
# 读取数据
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet3')

# 删除 'Group' 列中等于 3 的行
data = data[data['Cluster'] != 3]
# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ("reaction_times_in_incongruent_stimuli_at_baseline", "reaction_times_in_incongruent_stimuli_at_follow-up"),
    ("stroop_interference_effect_at_baseline", "stroop_interference_effect_at_follow-up"),
    ("accuracy_in_Nogo_trials_at_baseline", "accuracy_in_Nogo_trials_at_follow-up"),
    ("Switching_cost_at_baseline", "Switching_cost_at_follow-up"),
    ("accuracy_in_1750_ms_at_baseline", "accuracy_in_1750_ms_at_follow-up"),
    ("accuracy_in_750_ms_at_baseline", "accuracy_in_750_ms_at_follow-up"),
    ("span_in_digit_span_backward_task_at_baseline", "span_in_digit_span_backward_task_at_follow-up")
]

# 确保所有列名一致
required_columns = [
    'Cluster', 'Age', 
    'Education_years','Gender'
]

missing_columns = [col for col in required_columns if col not in data.columns]
if missing_columns:
    raise KeyError(f"The following required columns are missing from the data: {missing_columns}")

# 创建字典以存储结果
results = {}

# 对每个变量进行单因素协方差分析
def perform_ancova_analysis(symptom_var, time_point):
    # 选择特定时间点的数据
    if time_point == "baseline":
        df = data[[symptom_var] + required_columns]
    else:
        df = data[[symptom_var.replace("baseline", "follow-up")] + required_columns]
        df.columns = [col.replace("follow-up", "baseline") for col in df.columns]
    
    # 构建ANCOVA模型公式
    formula = (f"{symptom_var} ~ Cluster + Age + "
               "Education_years + " +
               " + ".join([col for col in required_columns if col != 'Cluster']))
    
    # 拟合模型
    model = ols(formula, data=df).fit()
    
    # 进行方差分析
    ancova_results = anova_lm(model, typ=2)
    
    # 对p值进行FDR BH校正
    p_values = ancova_results['PR(>F)'].values
    p_values_corrected = multipletests(p_values, method='fdr_bh')[1]
    ancova_results['PR(>F)_corrected'] = p_values_corrected
    
    # 返回结果
    return {
        'ANCOVA_summary': ancova_results,
        'Model_summary': model.summary()
    }

# 对每个变量在基线和随访时进行分析并存储结果
for baseline_var, followup_var in variables:
    # 基线分析
    results[baseline_var] = perform_ancova_analysis(baseline_var, "baseline")
    # 随访分析
    results[followup_var] = perform_ancova_analysis(baseline_var, "follow-up")

# 输出结果
for var, result in results.items():
    print(f"Variable: {var}")
    print(result['ANCOVA_summary'])
    print(result['Model_summary'])
    print("---")
# Out:
# Variable: reaction_times_in_incongruent_stimuli_at_baseline
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          2.856571e+04   1.0  1.246943  0.267799               NaN
# Age              8.746177e+03   1.0  0.381786  0.538572               NaN
# Education_years  7.243508e+02   1.0  0.031619  0.859359               NaN
# Gender           7.363760e+02   1.0  0.032144  0.858208               NaN
# Residual         1.672327e+06  73.0       NaN       NaN               NaN
#                                             OLS Regression Results
# =============================================================================================================
# Dep. Variable:     reaction_times_in_incongruent_stimuli_at_baseline   R-squared:                       0.029
# Model:                                                           OLS   Adj. R-squared:                 -0.024
# Method:                                                Least Squares   F-statistic:                    0.5509
# Date:                                               Wed, 18 Sep 2024   Prob (F-statistic):              0.699
# Time:                                                       10:46:57   Log-Likelihood:                -499.62
# No. Observations:                                                 78   AIC:                             1009.
# Df Residuals:                                                     73   BIC:                             1021.
# Df Model:                                                          4
# Covariance Type:                                           nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         667.1856     84.322      7.912      0.000     499.132     835.239
# Cluster            42.6763     38.218      1.117      0.268     -33.491     118.844
# Age                 1.2648      2.047      0.618      0.539      -2.815       5.344
# Education_years     0.8824      4.962      0.178      0.859      -9.007      10.772
# Gender              7.3487     40.988      0.179      0.858     -74.341      89.038
# ==============================================================================
# Omnibus:                        0.125   Durbin-Watson:                   2.165
# Prob(Omnibus):                  0.939   Jarque-Bera (JB):                0.213
# Skew:                          -0.091   Prob(JB):                        0.899
# Kurtosis:                       2.819   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: reaction_times_in_incongruent_stimuli_at_follow-up
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          6.883107e+02   1.0  0.036587  0.848840               NaN
# Age              4.112568e+03   1.0  0.218600  0.641501               NaN
# Education_years  6.416602e+03   1.0  0.341070  0.561013               NaN
# Gender           1.135282e+05   1.0  6.034504  0.016407               NaN
# Residual         1.373362e+06  73.0       NaN       NaN               NaN
#                                             OLS Regression Results
# =============================================================================================================
# Dep. Variable:     reaction_times_in_incongruent_stimuli_at_baseline   R-squared:                       0.098
# Model:                                                           OLS   Adj. R-squared:                  0.048
# Method:                                                Least Squares   F-statistic:                     1.974
# Date:                                               Wed, 18 Sep 2024   Prob (F-statistic):              0.107
# Time:                                                       10:46:57   Log-Likelihood:                -491.94
# No. Observations:                                                 78   AIC:                             993.9
# Df Residuals:                                                     73   BIC:                             1006.
# Df Model:                                                          4
# Covariance Type:                                           nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         589.9063     76.414      7.720      0.000     437.613     742.199
# Cluster            -6.6246     34.633     -0.191      0.849     -75.649      62.400
# Age                 0.8673      1.855      0.468      0.642      -2.830       4.564
# Education_years    -2.6262      4.497     -0.584      0.561     -11.588       6.336
# Gender             91.2458     37.144      2.457      0.016      17.217     165.274
# ==============================================================================
# Omnibus:                        0.462   Durbin-Watson:                   1.955
# Prob(Omnibus):                  0.794   Jarque-Bera (JB):                0.513
# Skew:                           0.175   Prob(JB):                        0.774
# Kurtosis:                       2.813   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: stroop_interference_effect_at_baseline
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          4.619359e+04   1.0  1.991051  0.162479               NaN
# Age              3.387320e+02   1.0  0.014600  0.904157               NaN
# Education_years  1.174967e+03   1.0  0.050644  0.822576               NaN
# Gender           8.528858e+02   1.0  0.036761  0.848484               NaN
# Residual         1.693644e+06  73.0       NaN       NaN               NaN
#                                       OLS Regression Results
# ==================================================================================================
# Dep. Variable:     stroop_interference_effect_at_baseline   R-squared:                       0.034
# Model:                                                OLS   Adj. R-squared:                 -0.019
# Method:                                     Least Squares   F-statistic:                    0.6359
# Date:                                    Wed, 18 Sep 2024   Prob (F-statistic):              0.639
# Time:                                            10:46:57   Log-Likelihood:                -500.12
# No. Observations:                                      78   AIC:                             1010.
# Df Residuals:                                          73   BIC:                             1022.
# Df Model:                                               4
# Covariance Type:                                nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -57.6947     84.858     -0.680      0.499    -226.816     111.427
# Cluster            54.2694     38.460      1.411      0.162     -22.382     130.921
# Age                 0.2489      2.060      0.121      0.904      -3.857       4.354
# Education_years     1.1238      4.994      0.225      0.823      -8.829      11.076
# Gender              7.9087     41.249      0.192      0.848     -74.300      90.117
# ==============================================================================
# Omnibus:                      101.137   Durbin-Watson:                   1.952
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1656.479
# Skew:                           4.116   Prob(JB):                         0.00
# Kurtosis:                      24.022   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: stroop_interference_effect_at_follow-up
#                         sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            2201.545971   1.0  0.529012  0.469349               NaN
# Age                6100.992837   1.0  1.466014  0.229881               NaN
# Education_years    4982.075207   1.0  1.197148  0.277490               NaN
# Gender             3464.899234   1.0  0.832584  0.364530               NaN
# Residual         303798.217944  73.0       NaN       NaN               NaN
#                                       OLS Regression Results
# ==================================================================================================
# Dep. Variable:     stroop_interference_effect_at_baseline   R-squared:                       0.039
# Model:                                                OLS   Adj. R-squared:                 -0.014
# Method:                                     Least Squares   F-statistic:                    0.7376
# Date:                                    Wed, 18 Sep 2024   Prob (F-statistic):              0.569
# Time:                                            10:46:57   Log-Likelihood:                -433.11
# No. Observations:                                      78   AIC:                             876.2
# Df Residuals:                                          73   BIC:                             888.0
# Df Model:                                               4
# Covariance Type:                                nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          37.0976     35.940      1.032      0.305     -34.530     108.725
# Cluster           -11.8475     16.289     -0.727      0.469     -44.312      20.616
# Age                -1.0564      0.872     -1.211      0.230      -2.795       0.682
# Education_years    -2.3141      2.115     -1.094      0.277      -6.529       1.901
# Gender             15.9407     17.470      0.912      0.365     -18.877      50.758
# ==============================================================================
# Omnibus:                       13.859   Durbin-Watson:                   2.137
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               53.345
# Skew:                           0.075   Prob(JB):                     2.61e-12
# Kurtosis:                       7.049   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: accuracy_in_Nogo_trials_at_baseline
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.010909   1.0  0.572651  0.451643               NaN
# Age              0.003377   1.0  0.177283  0.674956               NaN
# Education_years  0.007886   1.0  0.413923  0.522001               NaN
# Gender           0.003499   1.0  0.183691  0.669482               NaN
# Residual         1.390713  73.0       NaN       NaN               NaN
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     accuracy_in_Nogo_trials_at_baseline   R-squared:                       0.027
# Model:                                             OLS   Adj. R-squared:                 -0.026
# Method:                                  Least Squares   F-statistic:                    0.5149
# Date:                                 Wed, 18 Sep 2024   Prob (F-statistic):              0.725
# Time:                                         10:46:57   Log-Likelihood:                 46.372
# No. Observations:                                   78   AIC:                            -82.74
# Df Residuals:                                       73   BIC:                            -70.96
# Df Model:                                            4
# Covariance Type:                             nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.7446      0.077      9.684      0.000       0.591       0.898
# Cluster             0.0264      0.035      0.757      0.452      -0.043       0.096
# Age                 0.0008      0.002      0.421      0.675      -0.003       0.005
# Education_years     0.0029      0.005      0.643      0.522      -0.006       0.012
# Gender              0.0160      0.037      0.429      0.669      -0.058       0.091
# ==============================================================================
# Omnibus:                       36.381   Durbin-Watson:                   1.713
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               81.099
# Skew:                          -1.649   Prob(JB):                     2.45e-18
# Kurtosis:                       6.752   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: accuracy_in_Nogo_trials_at_follow-up
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.000844   1.0  0.039292  0.843422               NaN
# Age              0.016548   1.0  0.770161  0.383046               NaN
# Education_years  0.013428   1.0  0.624944  0.431777               NaN
# Gender           0.005624   1.0  0.261742  0.610470               NaN
# Residual         1.568479  73.0       NaN       NaN               NaN
#                                      OLS Regression Results
# ===============================================================================================
# Dep. Variable:     accuracy_in_Nogo_trials_at_baseline   R-squared:                       0.039
# Model:                                             OLS   Adj. R-squared:                 -0.014
# Method:                                  Least Squares   F-statistic:                    0.7401
# Date:                                 Wed, 18 Sep 2024   Prob (F-statistic):              0.568
# Time:                                         10:46:57   Log-Likelihood:                 41.680
# No. Observations:                                   78   AIC:                            -73.36
# Df Residuals:                                       73   BIC:                            -61.58
# Df Model:                                            4
# Covariance Type:                             nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.7046      0.082      8.629      0.000       0.542       0.867
# Cluster             0.0073      0.037      0.198      0.843      -0.066       0.081
# Age                 0.0017      0.002      0.878      0.383      -0.002       0.006
# Education_years     0.0038      0.005      0.791      0.432      -0.006       0.013
# Gender              0.0203      0.040      0.512      0.610      -0.059       0.099
# ==============================================================================
# Omnibus:                       31.132   Durbin-Watson:                   1.567
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               55.391
# Skew:                          -1.538   Prob(JB):                     9.38e-13
# Kurtosis:                       5.754   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: Switching_cost_at_baseline
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          3.102536e+03   1.0  0.031586  0.859432               NaN
# Age              1.007757e+05   1.0  1.025958  0.314455               NaN
# Education_years  3.661438e+03   1.0  0.037276  0.847441               NaN
# Gender           4.121510e+02   1.0  0.004196  0.948529               NaN
# Residual         7.170499e+06  73.0       NaN       NaN               NaN
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Switching_cost_at_baseline   R-squared:                       0.014
# Model:                                    OLS   Adj. R-squared:                 -0.040
# Method:                         Least Squares   F-statistic:                    0.2676
# Date:                        Wed, 18 Sep 2024   Prob (F-statistic):              0.898
# Time:                                10:46:57   Log-Likelihood:                -556.40
# No. Observations:                          78   AIC:                             1123.
# Df Residuals:                              73   BIC:                             1135.
# Df Model:                                   4
# Covariance Type:                    nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         403.4410    174.604      2.311      0.024      55.455     751.427
# Cluster            14.0645     79.137      0.178      0.859    -143.655     171.784
# Age                -4.2933      4.239     -1.013      0.314     -12.741       4.154
# Education_years     1.9838     10.275      0.193      0.847     -18.495      22.462
# Gender              5.4978     84.874      0.065      0.949    -163.656     174.651
# ==============================================================================
# Omnibus:                        5.735   Durbin-Watson:                   2.106
# Prob(Omnibus):                  0.057   Jarque-Bera (JB):                4.978
# Skew:                           0.579   Prob(JB):                       0.0830
# Kurtosis:                       3.435   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: Switching_cost_at_follow-up
#                        sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          1.236533e+05   1.0  1.676888  0.199419               NaN
# Age              1.033782e+05   1.0  1.401933  0.240241               NaN
# Education_years  4.994427e+05   1.0  6.773044  0.011201               NaN
# Gender           1.848188e+05   1.0  2.506366  0.117710               NaN
# Residual         5.383003e+06  73.0       NaN       NaN               NaN
#                                 OLS Regression Results
# ======================================================================================
# Dep. Variable:     Switching_cost_at_baseline   R-squared:                       0.174
# Model:                                    OLS   Adj. R-squared:                  0.129
# Method:                         Least Squares   F-statistic:                     3.854
# Date:                        Wed, 18 Sep 2024   Prob (F-statistic):            0.00676
# Time:                                10:46:57   Log-Likelihood:                -545.22
# No. Observations:                          78   AIC:                             1100.
# Df Residuals:                              73   BIC:                             1112.
# Df Model:                                   4
# Covariance Type:                    nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         395.4956    151.284      2.614      0.011      93.987     697.004
# Cluster           -88.7907     68.567     -1.295      0.199    -225.445      47.863
# Age                -4.3484      3.673     -1.184      0.240     -11.668       2.971
# Education_years    23.1696      8.903      2.603      0.011       5.426      40.913
# Gender           -116.4217     73.538     -1.583      0.118    -262.983      30.139
# ==============================================================================
# Omnibus:                       11.234   Durbin-Watson:                   2.105
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.713
# Skew:                           0.928   Prob(JB):                      0.00286
# Kurtosis:                       3.397   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: accuracy_in_1750_ms_at_baseline
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.166770   1.0  2.599748  0.111196               NaN
# Age              0.224981   1.0  3.507181  0.065108               NaN
# Education_years  0.018937   1.0  0.295203  0.588561               NaN
# Gender           0.001201   1.0  0.018729  0.891524               NaN
# Residual         4.682846  73.0       NaN       NaN               NaN
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     accuracy_in_1750_ms_at_baseline   R-squared:                       0.077
# Model:                                         OLS   Adj. R-squared:                  0.026
# Method:                              Least Squares   F-statistic:                     1.518
# Date:                             Wed, 18 Sep 2024   Prob (F-statistic):              0.206
# Time:                                     10:46:57   Log-Likelihood:               -0.97790
# No. Observations:                               78   AIC:                             11.96
# Df Residuals:                                   73   BIC:                             23.74
# Df Model:                                        4
# Covariance Type:                         nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.4595      0.141      3.257      0.002       0.178       0.741
# Cluster            -0.1031      0.064     -1.612      0.111      -0.231       0.024
# Age                 0.0064      0.003      1.873      0.065      -0.000       0.013
# Education_years    -0.0045      0.008     -0.543      0.589      -0.021       0.012
# Gender             -0.0094      0.069     -0.137      0.892      -0.146       0.127
# ==============================================================================
# Omnibus:                        2.281   Durbin-Watson:                   1.986
# Prob(Omnibus):                  0.320   Jarque-Bera (JB):                1.870
# Skew:                          -0.237   Prob(JB):                        0.393
# Kurtosis:                       2.407   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: accuracy_in_1750_ms_at_follow-up
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.647280   1.0  8.824738  0.004021               NaN
# Age              0.001655   1.0  0.022561  0.881018               NaN
# Education_years  0.006182   1.0  0.084284  0.772396               NaN
# Gender           0.335013   1.0  4.567429  0.035936               NaN
# Residual         5.354427  73.0       NaN       NaN               NaN
#                                    OLS Regression Results
# ===========================================================================================
# Dep. Variable:     accuracy_in_1750_ms_at_baseline   R-squared:                       0.143
# Model:                                         OLS   Adj. R-squared:                  0.096
# Method:                              Least Squares   F-statistic:                     3.042
# Date:                             Wed, 18 Sep 2024   Prob (F-statistic):             0.0224
# Time:                                     10:46:57   Log-Likelihood:                -6.2046
# No. Observations:                               78   AIC:                             22.41
# Df Residuals:                                   73   BIC:                             34.19
# Df Model:                                        4
# Covariance Type:                         nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.4729      0.151      3.134      0.002       0.172       0.774
# Cluster            -0.2031      0.068     -2.971      0.004      -0.339      -0.067
# Age                -0.0006      0.004     -0.150      0.881      -0.008       0.007
# Education_years    -0.0026      0.009     -0.290      0.772      -0.020       0.015
# Gender              0.1567      0.073      2.137      0.036       0.011       0.303
# ==============================================================================
# Omnibus:                        3.142   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.208   Jarque-Bera (JB):                2.270
# Skew:                          -0.250   Prob(JB):                        0.321
# Kurtosis:                       2.331   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: accuracy_in_750_ms_at_baseline
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.260315   1.0  3.115448  0.081735               NaN
# Age              0.002695   1.0  0.032258  0.857961               NaN
# Education_years  0.083679   1.0  1.001469  0.320261               NaN
# Gender           0.403192   1.0  4.825395  0.031219               NaN
# Residual         6.099613  73.0       NaN       NaN               NaN
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     accuracy_in_750_ms_at_baseline   R-squared:                       0.078
# Model:                                        OLS   Adj. R-squared:                  0.028
# Method:                             Least Squares   F-statistic:                     1.549
# Date:                            Wed, 18 Sep 2024   Prob (F-statistic):              0.197
# Time:                                    10:46:57   Log-Likelihood:                -11.286
# No. Observations:                              78   AIC:                             32.57
# Df Residuals:                                  73   BIC:                             44.36
# Df Model:                                       4
# Covariance Type:                        nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.4575      0.161      2.841      0.006       0.137       0.778
# Cluster            -0.1288      0.073     -1.765      0.082      -0.274       0.017
# Age                -0.0007      0.004     -0.180      0.858      -0.008       0.007
# Education_years    -0.0095      0.009     -1.001      0.320      -0.028       0.009
# Gender              0.1720      0.078      2.197      0.031       0.016       0.328
# ==============================================================================
# Omnibus:                        8.835   Durbin-Watson:                   2.261
# Prob(Omnibus):                  0.012   Jarque-Bera (JB):                3.072
# Skew:                           0.021   Prob(JB):                        0.215
# Kurtosis:                       2.029   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: accuracy_in_750_ms_at_follow-up
#                    sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster          0.252143   1.0  3.548424  0.063585               NaN
# Age              0.133241   1.0  1.875113  0.175089               NaN
# Education_years  0.040564   1.0  0.570858  0.452349               NaN
# Gender           0.169944   1.0  2.391637  0.126310               NaN
# Residual         5.187221  73.0       NaN       NaN               NaN
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     accuracy_in_750_ms_at_baseline   R-squared:                       0.112
# Model:                                        OLS   Adj. R-squared:                  0.063
# Method:                             Least Squares   F-statistic:                     2.298
# Date:                            Wed, 18 Sep 2024   Prob (F-statistic):             0.0670
# Time:                                    10:46:57   Log-Likelihood:                -4.9673
# No. Observations:                              78   AIC:                             19.93
# Df Residuals:                                  73   BIC:                             31.72
# Df Model:                                       4
# Covariance Type:                        nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           0.4622      0.149      3.112      0.003       0.166       0.758
# Cluster            -0.1268      0.067     -1.884      0.064      -0.261       0.007
# Age                -0.0049      0.004     -1.369      0.175      -0.012       0.002
# Education_years     0.0066      0.009      0.756      0.452      -0.011       0.024
# Gender              0.1116      0.072      1.546      0.126      -0.032       0.256
# ==============================================================================
# Omnibus:                        2.568   Durbin-Watson:                   2.155
# Prob(Omnibus):                  0.277   Jarque-Bera (JB):                1.626
# Skew:                          -0.074   Prob(JB):                        0.443
# Kurtosis:                       2.308   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: span_in_digit_span_backward_task_at_baseline
#                      sum_sq    df         F    PR(>F)  PR(>F)_corrected
# Cluster            3.827873   1.0  1.365466  0.246394               NaN
# Age                3.013196   1.0  1.074858  0.303273               NaN
# Education_years    1.181848   1.0  0.421585  0.518185               NaN
# Gender             0.621238   1.0  0.221606  0.639223               NaN
# Residual         204.644141  73.0       NaN       NaN               NaN
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     span_in_digit_span_backward_task_at_baseline   R-squared:                       0.056
# Model:                                                      OLS   Adj. R-squared:                  0.005
# Method:                                           Least Squares   F-statistic:                     1.092
# Date:                                          Wed, 18 Sep 2024   Prob (F-statistic):              0.367
# Time:                                                  10:46:57   Log-Likelihood:                -148.30
# No. Observations:                                            78   AIC:                             306.6
# Df Residuals:                                                73   BIC:                             318.4
# Df Model:                                                     4
# Covariance Type:                                      nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.0554      0.933      6.492      0.000       4.196       7.914
# Cluster            -0.4940      0.423     -1.169      0.246      -1.337       0.349
# Age                -0.0235      0.023     -1.037      0.303      -0.069       0.022
# Education_years     0.0356      0.055      0.649      0.518      -0.074       0.145
# Gender             -0.2134      0.453     -0.471      0.639      -1.117       0.690
# ==============================================================================
# Omnibus:                       11.001   Durbin-Watson:                   2.319
# Prob(Omnibus):                  0.004   Jarque-Bera (JB):               11.124
# Skew:                           0.867   Prob(JB):                      0.00384
# Kurtosis:                       3.644   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---
# Variable: span_in_digit_span_backward_task_at_follow-up
#                      sum_sq    df          F    PR(>F)  PR(>F)_corrected
# Cluster           31.668835   1.0  14.120271  0.000343               NaN
# Age                5.961702   1.0   2.658160  0.107327               NaN
# Education_years   12.958743   1.0   5.777951  0.018768               NaN
# Gender             0.037129   1.0   0.016555  0.897976               NaN
# Residual         163.723836  73.0        NaN       NaN               NaN
#                                          OLS Regression Results
# ========================================================================================================
# Dep. Variable:     span_in_digit_span_backward_task_at_baseline   R-squared:                       0.305
# Model:                                                      OLS   Adj. R-squared:                  0.267
# Method:                                           Least Squares   F-statistic:                     8.018
# Date:                                          Wed, 18 Sep 2024   Prob (F-statistic):           2.05e-05
# Time:                                                  10:46:57   Log-Likelihood:                -139.59
# No. Observations:                                            78   AIC:                             289.2
# Df Residuals:                                                73   BIC:                             301.0
# Df Model:                                                     4
# Covariance Type:                                      nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept           6.0003      0.834      7.192      0.000       4.337       7.663
# Cluster            -1.4210      0.378     -3.758      0.000      -2.175      -0.667
# Age                -0.0330      0.020     -1.630      0.107      -0.073       0.007
# Education_years     0.1180      0.049      2.404      0.019       0.020       0.216
# Gender              0.0522      0.406      0.129      0.898      -0.756       0.860
# ==============================================================================
# Omnibus:                        3.967   Durbin-Watson:                   2.102
# Prob(Omnibus):                  0.138   Jarque-Bera (JB):                3.706
# Skew:                           0.533   Prob(JB):                        0.157
# Kurtosis:                       2.946   Cond. No.                         184.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# ---

# %%
import pandas as pd
from scipy import stats
from statsmodels.stats.multitest import multipletests
import warnings

warnings.filterwarnings('ignore')
data = pd.read_excel('./rawdata.xlsx', sheet_name='Sheet3')

# 删除 'Group' 列中等于 3 的行
data = data[data['Cluster'] != 3]
# 将列名中的空格替换为下划线,去掉逗号
data.columns = [col.replace(' ', '_').replace(',', '') for col in data.columns]

# 定义要检测的变量
variables = [
    ("reaction_times_in_incongruent_stimuli_at_baseline", "reaction_times_in_incongruent_stimuli_at_follow-up"),
    ("stroop_interference_effect_at_baseline", "stroop_interference_effect_at_follow-up"),
    ("accuracy_in_Nogo_trials_at_baseline", "accuracy_in_Nogo_trials_at_follow-up"),
    ("Switching_cost_at_baseline", "Switching_cost_at_follow-up"),
    ("accuracy_in_1750_ms_at_baseline", "accuracy_in_1750_ms_at_follow-up"),
    ("accuracy_in_750_ms_at_baseline", "accuracy_in_750_ms_at_follow-up"),
    ("span_in_digit_span_backward_task_at_baseline", "span_in_digit_span_backward_task_at_follow-up")
]

# 创建字典以存储结果
results = {}

# 定义函数进行配对t检验
def perform_paired_ttest(group, baseline_var, followup_var):
    baseline_scores = data[data['Cluster'] == group][baseline_var]
    followup_scores = data[data['Cluster'] == group][followup_var]
    
    # 进行配对t检验
    t_stat, p_value = stats.ttest_rel(baseline_scores, followup_scores)
    
    return p_value

# 对每个变量在两个亚组进行分析并存储结果
for baseline_var, followup_var in variables:
    p_values_group1 = perform_paired_ttest(0, baseline_var, followup_var)
    p_values_group2 = perform_paired_ttest(1, baseline_var, followup_var)
    
    # 将结果存储在字典中
    results[(baseline_var, 'Group1')] = p_values_group1
    results[(baseline_var, 'Group2')] = p_values_group2

# 将p值进行FDR BH校正
p_values = list(results.values())
p_values_corrected = multipletests(p_values, method='fdr_bh')[1]

# 更新结果字典
corrected_results = {}
for i, key in enumerate(results.keys()):
    corrected_results[key] = p_values_corrected[i]

# 输出结果
for var in variables:
    print(f"Variable: {var[0]}")
    print(f"Group 1 (Subtype I) p-value (corrected): {corrected_results[(var[0], 'Group1')]:.4f}")
    print(f"Group 2 (Subtype II) p-value (corrected): {corrected_results[(var[0], 'Group2')]:.4f}")
    print("---")
# Out:
# Variable: reaction_times_in_incongruent_stimuli_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.4989
# Group 2 (Subtype II) p-value (corrected): 0.1437
# ---
# Variable: stroop_interference_effect_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.3365
# Group 2 (Subtype II) p-value (corrected): 0.3492
# ---
# Variable: accuracy_in_Nogo_trials_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.7906
# Group 2 (Subtype II) p-value (corrected): 0.7413
# ---
# Variable: Switching_cost_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.4989
# Group 2 (Subtype II) p-value (corrected): 0.3365
# ---
# Variable: accuracy_in_1750_ms_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.8474
# Group 2 (Subtype II) p-value (corrected): 0.3365
# ---
# Variable: accuracy_in_750_ms_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.7680
# Group 2 (Subtype II) p-value (corrected): 0.3365
# ---
# Variable: span_in_digit_span_backward_task_at_baseline
# Group 1 (Subtype I) p-value (corrected): 0.0373
# Group 2 (Subtype II) p-value (corrected): 0.7491
# ---
